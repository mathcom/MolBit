# %%
import os
import sys
import math
import pandas as pd
import numpy as np
import time
import torch
from tqdm import tqdm, trange
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %%
sys.path.append("./bin")
from dataset import SmilesEncoder
from vae import SmilesVAE
from rewards import RewardQED, RewardPenalizedLogP

# %%
output_dir = "output_1_pretrain_SmilesVAE_ZINC"

# %%
filepath_tokenizer = os.path.join(output_dir, "char2idx.csv")

tokenizer = SmilesEncoder(filepath_tokenizer)
# Out:
# Vocabulary size (including 3 special tokens): 28

# %%
generator = SmilesVAE(vocab_size=tokenizer.vocab_size,
                      embedding_size=16,
                      hidden_size=256,
                      latent_size=64,
                      sos_idx=tokenizer.sos_idx,
                      eos_idx=tokenizer.eos_idx,
                      pad_idx=tokenizer.pad_idx,
                      device=device)

filepath_model = os.path.join(output_dir, "SmilesVAE.pt")
generator.load_model(filepath_model)

# %%
rng = np.random.RandomState(2021)
latent_vectors = rng.randn(10,64)

# %%
smiles_per_z = []
n_generate = 1000

with torch.no_grad():
    for z in latent_vectors:
        z = torch.cuda.FloatTensor(z, device=device)
        smiles = []
        for _ in trange(n_generate):
            smi = generator.inference(z)
            smi = tokenizer.decode([smi])[0]
            smiles.append(smi)
        smiles_per_z.append(smiles)
# Out:
# 100%|██████████| 1000/1000 [00:32<00:00, 31.00it/s]
# 100%|██████████| 1000/1000 [00:32<00:00, 30.47it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 30.27it/s]
# 100%|██████████| 1000/1000 [00:32<00:00, 30.32it/s]
# 100%|██████████| 1000/1000 [00:32<00:00, 30.55it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 30.05it/s]
# 100%|██████████| 1000/1000 [00:32<00:00, 30.59it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.91it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.82it/s]
# 100%|██████████| 1000/1000 [00:32<00:00, 30.42it/s]

# %%
smiles
# Out:
# ['CC(C1=CC=CC=C1F)N(CC1=CC=CC(C(N)=O)=C1)C(C)=O',
#  'COC1=CC(C=NNC(=O)C2=NN3CC(=O)N(C)C4=C2N=NN3C2=CC=CC=C2)=CC(C)=C1OCCC',
#  'COC1=CC=C(C(=O)C2CCN(C3=NN=NN3CC3=CC=CC=N3)CC2)C=C1',
#  'OC1=CC=C(CSC2=NN=C(C3=CC=CC=C3)N2C2=CC=CC=C2)C=C1',
#  'COC(C1=CC=C(Cl)C=C1)C1CCC1',
#  'CCC([NH3+])CC1=CC(C2CC2)NC2=CC=CC=C2C1=O',
#  'CC1=CC(C)=C(C(=O)C2=CC3=CC=CC=C3N2)C(C(=O)[O-])=C1C',
#  'COC1=CC=C(C=[NH+]C(CO)C(=O)[O-])C(OC)=C1OC',
#  'CN(CCCC1=CC=CC=C1)C1=NC(C[NH+](C)C)=CC(O)=C1C#N',
#  'CC1CN(C(=O)CSC2=NC=CN(C)C2=O)CC(C)O1',
#  'COC(=O)C(C)C(N)C1=CC=C(F)C=C1',
#  'COC1=CC(C(=O)N2CCC(CO)C(O)C2)=CC(OC)=C1OC',
#  'CC1=NOC(CN(C)C(=O)C2=C(C)N=C(C3=CC=C4C=CC=CC4=C3)O2)=C1',
#  'CC(=NNC(=O)C1CC2CCC(C1)[NH2+]2)C1=CC=C(OC(F)F)C=C1',
#  'O=C(NC1=CC=C(F)C=C1Cl)C1=CC=C(C=CC2NCC(=O)N2CCCCCC(Cl)(Cl)Cl2',
#  'CCC(C)(NC(=O)C1CCC1)C(=O)OC',
#  'CC1=CC(NC(=O)C(C)OC2=CC=C(F)C=C2)=NC(N)=N1',
#  'CC1[NH2+]CCCOC1C(=O)C1=CC=CC=C1',
#  'O=C(C1=CC=CC=C1CCC1CCCCC1)N1CCCCN(C2=CC=CC(C(F)(F)F)=C2)C1',
#  'CC1=CC=CC(NC(=O)CCC2=C(C3=CC=CC=C3)N=C3C(C)=NN(C)C3=N2)=C1',
#  'CC1=C(C(=O)OCC2CCCO2)C=C(Br)S1',
#  'CCOC1=CC=C(NC(=O)NCCCN2CCCC3=CC=CC=C32)C(C)=C1',
#  'CC(=O)N(CCC1=NC(C)=NC=C1C)C1CCOC2(CCCC2)C1',
#  'CC1(C)C(NC(=O)N(CC2=CC=CC=C2Cl)C(C)(C)C)C1(C)C',
#  'CC1=CC(N2CCCC3CC[NH+](CC(=O)NC4CCC(=O)N(C)C4)=NC=C3C2)=NC=N1',
#  'COC1=CC=C(CC(=O)N2CC3=C(CC(C4=CC=CC(F)=C4)CCO3)C2OC(C)C2=CC=CO2)C=C1',
#  'CCCCN1C(=O)CCC2=CC(OC(=O)C[NH+](C)C(C)C)=CC(OC)=C21',
#  'CCCN1N=C(C(=O)NC2=CC=C3C=CC=CC3=C2)C=CC1=O',
#  'COC(=O)NC1=C(C(C)=O)C(C2=CC=CC=C2OC)C2=CC=CC=C2N1',
#  'CN1C(=O)C2=CC=CC=C2C(=O)N1CC(=O)N1CCN(CCO)CC1',
#  'CN1C(=NN=CC2=CC=C(C3=CC=C(Br)O3)S2)OC2=CC=CC=C21',
#  'CCS(=O)(=O)C1=CC=CC=C1NC(=O)CSCC1=CC=C(C#N)C(C)=C1',
#  'CCCOC(C)C1CCC[NH+](CC(=O)NC2=CC=CC(C)=C2F)C1',
#  'CC1=CC=CN=C1NC(=O)C1=C(C)N(C2CC[NH+](C)CC2)N=C1C(=O)[O-]',
#  'O=C(N1CCC2(C1)NC2=CC=C(F)C=C1F)C1=CC=C2C=CC=CC2=N1',
#  'CC1=CC=C(NC(=O)CSC2=NC3=CC=CC=C3C(=O)N2C2=CC=C3C=CC=CC3=C2)C=C1',
#  'CCOCCOC1=CC=CC(NC(=O)N2CC3CCCCC3C2)=C1',
#  'CCCC([NH3+])C1=CN(CC(=O)NC(C)C)C(C)=C1',
#  'CC(=O)N1CCC(C(=O)NC2=CC=CC3=C2C(=CC=CN2C)C3=O)CC2=O)CC1',
#  'CC1=NOC(C)=C1CN1CCN(C(=O)C2=CC=C(CN3CC(C)OCC3)C=C2)CC1',
#  'COC1=CC(C2C3=C(OC4=CC=CC=C4C3=O)C(=O)N2CC(O)CSC)=CC=C1O',
#  'CSC(=NC1=C(C(N)=O)C2=C(CCCCC2)S1)N1CC[NH+](C2CCCC2)CC1',
#  'CC(C)C1=NN(C)C2=C1NC(=O)CC(SCC1=CC=CC=N1)C2=O',
#  'CC(C)C1OC([O-])=NC(SC2=CC=C(F)C(Br)=C2)=N1',
#  'CCC(C)C(CCNC(NC1CC1)N(C)CC1=CC=CC=C1',
#  'CN(CC1CCC[NH+]1C)C(=O)C1=CC2=CN=C(C2=CC=CC=N1)S1',
#  'CC1=CC=C(C(=O)NC2=CN=C(C3=CC=CN=C3)N=C2C)C(C)=C1',
#  'COC1=CC=C(C(N)=O)C=C1NC(=O)COC(C)(C)C',
#  'CCNC(C)C1=NC(C)=NO1',
#  'CC([NH2+]CC(F)(F)F)C(C)(C1=CC=CC=C1)C1=CC=CC=C1',
#  'COC1=CC(CNC(=O)N2CC3CC=CCC3C2)=CC(OC)=C1',
#  'CC(OC1=CC=CC(F)=C1)C(=O)N1CC[NH+](CC=CC2=CC=CC=C2)CC1',
#  'CC1=CC=C(C)C(N(C)C(=O)CN2CCN(C3=CC(F)=CC(F)=C3F)CC2)=C1',
#  'CC(=O)N1CCN(C(=O)NCCC2=CC=C(CN3N=NC4=CC=CC=C4C3=O)C=C2)CC1',
#  'O=S1(=O)CC(O)C(NS(=O)(=O)C2=CC=C(OCC(F)F)N(C3CC3)C2)C1',
#  'COC1=CC=CC(C2=COC(C3=CC=CN=C3)=N2)=C1O',
#  'CC1OCCC1CS(=O)CC1=C(Cl)SC(Cl)=C1',
#  'COC(=O)C(Cl)C1=CC=C(Cl)C(S(=O)(=O)N2CCCC2)=C1',
#  'COC1=CC=C(C[NH2+]CC2C[NH+]3CCN2CC3)C=C1CO',
#  'CCC(C)NC(=O)NCC1(C2=CC=CC(C)=C2)CCOCC1',
#  'CCN(CC)C(=O)NC1=CC(C2=CC=CO2)=NN=C1C1CC(=O)N(C2CCCC2)C1',
#  'CC(NC(=O)C1=NOC=C1)C1=CC=C(S(C)(=O)=O)C=C1',
#  'CC1=CC(C)=C2C(C(=O)NNC(=O)C3CCCO3)=CC=CC2=C1',
#  'CNC(=O)C1CC2=C([O-])NN=C2C1',
#  'CC1=CC(=O)NC(SCC(=O)C2=CC=C(Cl)C=C2)=N1',
#  'CC1=NC(C#CC[NH2+]C(C)C2=CN(C)N=C2C)=CS1',
#  'COC1=CC=CC(CNC(=O)NC2=CC=CC(C#N)=C2)=C1O',
#  'O=C(COC1=CC=CC(Br)=C1)NC1CC1',
#  'COC(=O)NC1CCC[NH+](CC(O)COC2=CC=CC(F)=C2)C1',
#  'CC(C)COC(=O)N1CCCCC1',
#  'CC1=C(C)SC(N2CCN(C(=O)CCCN3N=C(C)N(C4CCCCC4)C3=O)CC2)=N1',
#  'C1=CSC(C2=NN(C3=CC=CC=C3)C(C3CCC[NH+]3CC34CCO5)CC3)=C2C=C1',
#  'ClC1=CC=C(N2CC[NH+](CC3=CN=NN3C)CC2)C=C1',
#  'CC1=CC=C(C(=O)NC(C[NH+]2CCCCCC2)C2=CC=CC=C2)C=C1',
#  'O=[N+]([O-])C1=CC=C(C2=NOC3=NC(SCC4=CC=NC4=C([O-])=CC=C4OC3=O)=C2)C=C1',
#  'CC(SC1=NN=CN1C1=CC=C(Cl)C=C1)C1=NC2=CC(Cl)=CC=C2N1',
#  'CCC1=C(C(=O)NC2CCCOC2=O)SC(Cl)=N1',
#  'COC1=CC=C(Br)C(C(=O)OCC(=O)NC2=CC=CC(C#N)=C2)=C1',
#  'CCCNC(C1=CN=CC(Br)=C1)C1=CN(C)C2=CC=CC=C12',
#  'CCC(NC(=O)NC1=NC(C(=O)N(C)C)=NS1)C1=CC=CC=C1',
#  'COCCC1CCCCN1CC1=CC(C)=NO1',
#  'CCC(CC)C(O)CNC(=O)CN1C=CC(=O)C2=CC(F)=CC=C21',
#  'CC1=C(C)SC(CC2=CC=CC=C2)=N1',
#  'CCC(NC1=NC(C#CCO)=CS1)C1=CC=C(C(C)(C)C)C=C1',
#  'CC1CCN(S(=O)(=O)C2=CN(C)C=C2)CC1',
#  'CCCC(C)NC(=O)C1(CC(=O)N2CCCCC2C)CCCC1',
#  'CC(=O)N1CCN(C(=O)CC2=NOC(C3=CC=CC=C3)=C2)CC1',
#  'CC(CC(=O)[O-])CCCC1=CC=C(OCC(N)=O)C=C1',
#  'COC1=CC=C(C(C)SCC2=NOC(C)=N2)C=C1OC',
#  'O=C1[NH+]=C(N2CCOCC2)OC2=CC=CC(C(=O)NC3=CC=C(F)C=C3)=C12',
#  'CCC1=NN(C)C=C1CNC(=O)NC1CCN(C2=CC=C(C(F)(F)F)C=N2)CC1',
#  'CC1(C)C(NS(=O)(=O)CC2CCCCO2)CC1C',
#  'CCCC1=CC(C(=O)NCCC2=NNC(=O)C=C2)=NO1',
#  'CC1=NOC(C)=C1COC1=CC=C(CNC2=CC=CN=N2)C=C1',
#  'COC1=CC=C(OCC(=O)NCCNC(=O)C2=CC=CC(Cl)=C2)C=C1',
#  'CS(=O)(=O)C1CCCC1(O)C(=O)NN',
#  'CCC(C)N(C(=O)C(C)[NH+]1CCC2=C(C=CC3=CC=CC=C32)O1)C1CCS(=O)(=O)C1',
#  'COC1=CC=CC2=C1N=C(NC(=O)CC1=CC=CC=C1Br)S2',
#  'COCCN1C(SCC(=O)[O-])=NC2=C(OC3=CC=CC=C32)N1CC1CCCO1',
#  'CC(CC1=CN(C)N=C1)[NH2+]CC(O)C1=CC=CC(F)=C1',
#  'C[NH+](CC(=O)NC1CCN(C(=O)C(C)(C)C)C1)C1CCS(=O)(=O)C1',
#  'ClC1=CC(CN2CCOCC2)=CC=C1F',
#  'CC(NC1CC(=O)N(C2CC2)C1C)C1=CC=C(C2=CC=NC=C2)C=C1',
#  'COC1=CC=CC=C1C1OC2=CC=CC=C2OC1C(=O)NC1=NN=C(C)S1',
#  'CC1=CC=C(S(=O)(=O)N(C(=O)C2=CN=C3C=C(C)C=CN3CC(F)(F)F)C2)C=C1',
#  'COCCCNC(=O)CCC',
#  'CC1=CC=C2C(=O)N(CC3=CC=C(C4=NNC=C4)N=C3)C(=O)C2=C1',
#  'CCOC1=C(Cl)C=C(C=CC(=O)OCC2=CC=CC(O)=C2)C=C1OC',
#  'CC1=CC=CC(F)=C1C(=O)NC1=CC=C(N)C=C1',
#  'CSC1=CC=CC=C1C(=O)OC(C(=O)NC1=C(C)C=C(Br)C=C1C)C1=CC=CC=C1',
#  'CCC(C)(NC(=O)NC1CCOC1C1=CC=C(Cl)C=C1)C(=O)[O-]',
#  'CC(OC(=O)C1=CC([N+](=O)[O-])=CC=C1N1CCOCC1)C1=CC=C(Cl)C=C1',
#  'CC[NH+](CC)C1CCN(C(=O)C2CCOC2C)C1',
#  'CC(NC1=CC=C(Cl)C=C1)(C(=O)[O-])C(F)(F)F',
#  'CN1C=CC(NC2=NC3=NC=CC=C3N2)=N1',
#  'O=C(NC1=CN=C2C=CC=CC2=C1)C1=CC=C2OCCOC2=C1',
#  'CC1=C(C(=O)NC2CCCC(OC)C2)SC=N1',
#  'COC1=CC=CC(CNC(=O)NCC2=NOC(COC)=C2)=C1',
#  'O=S1(=O)CCC(C[NH2+]CC2=NC=CS2)C1',
#  'CCN1N=NC2=CC(C(=O)OCCN3C=NC=N3)=CC=C21',
#  '[NH3+]C(CO)C(=O)NCC1COC2=CC=CC=C2O1',
#  'O=S(CC1=CC=CC2=CC=CC=C12)C1=NC=CS1',
#  'COC1=CC=CC(C2NN3C(=NN=C3C3=CC=CC=C3)C3=CC=CC=C3C2=O)=C1',
#  'COCC1=CC(C)=CC(CC[NH2+]C2CCC3=CC=CC=C32)=C1',
#  'CC1=C(C)SC(NC(=O)CCC(F)(F)F)=N1',
#  'CC1CC(OCC(O)C[NH+](C)CC2CC3=CC=CC=C32)CC(C)O1',
#  'CC1=CSC(C[NH+](C)CC(C)S(C)(=O)=O)=N1',
#  'CCNS(=O)(=O)CC1(CC(C)C)CCCCC1',
#  'CCC1C[NH+](CC2=CC=C(C)C(C#N)=C2)C1',
#  'CC(C)CC1CCCCN1C(=O)C=CC1=CC(F)=C([)S(F)F)C=C1',
#  'CCC(O)C[NH+](C)C(C)CC1=CC=C(OC)C=C1',
#  'O=C([O-])CC1CN(C(=O)C[NH+]2CCCCC2)C1(C1=CC=CC=C1)C1=NC=CS1',
#  'O=C(NCCCC1CCC[NH2+]C1)C1=CC=C2C(=O)NNC2=C1',
#  'C=CCC(C#N)=C(S(=O)(=O)C1=CC=C(C(C)C)C=C1)C(C)O',
#  'CC1(C2=CC(O)=NC=C2C2=CN=CN=C2)CCCO1',
#  'CC1=NC(SCC(=O)NC2=CC=C3OCOC3=C2)=C2N=NN=C2C=C1',
#  'CC(C)NC(=O)CN1CCN(C(=O)C2CSCCO2)CC1',
#  'CC1=CC=C(C(=O)NC2=CC=C(Cl)C=C2N)C=C1',
#  'COC1=CC=C(C(=O)N(C)CC2=CC=C(Cl)C=C2)C=C1[N+](=O)[O-]',
#  'CCCNC(=O)N1CCN(CC(=O)N(C2CC2)C2CCCCC2)CC1',
#  'FC(F)(F)CN1CCN(S(=O)(=O)C2=CC(Cl)=CC(Cl)=C2)CC1',
#  'CC(=O)NC1=CC=C(C(=O)NCC2=CC=CC(CN3C=CN=C3)=C2)C(C)=C1',
#  'CN(C)C(=O)CSC1=NN=NN1C1CCCCC1',
#  'COC(=O)C(NCC(C)CC1=CC=CC=C1)C1CCCC1',
#  'CCC(C)CN(CC)C1=NN=NN1C1=CC=C(C)C(C)=C1',
#  'O=C(CSCC1CCCO1)N1CCCC2=CC=CC=C21',
#  'CON=CC1=CC=C(C(=O)NC2CCC(C)C(O)C2)C=C1',
#  'CC(OC(=O)C1=CC=C(Br)N=C1)C1=CC=C(OC2=CC=CC=C2Cl)C=C1',
#  'COC1=CC=CC(NC(=O)N2CCC(N3C(C[NH+](C)C)C4CC3)CC2)=C1',
#  'COCC1=CC=C(C(=O)NC2CC[NH+](C3CCOCC3)CC2)C=C1',
#  'CCOC1=CC=C(C(C)[NH+]2CCC(OCC3CCCO3)CC2)C=C1',
#  'CC(C)(C)C1CCC([NH+]2CCC(OC3=CC=C(F)C=C3)C2)CC1',
#  'CC1=NN(C)C(C)=C1C(=O)NC(C(=O)NC1=CC=CC=C1)C1=NN=C(C2=CC=CC=C2)O1',
#  'C[NH+]=C(NCC1=NC(C2=CC=C(F)C=C2)=CS1)N1CCCC1',
#  'CC1=NN=C(SCC2=CC=CC=C2Cl)N1N',
#  'CCOC1=CC=C2N=C(N(CCCN3CC[NH+](C)CC(C)CC)C4=O)SC3=C2)C=C1C',
#  'CC1=C(C(=O)NC(C2=CC=CC=C2)C2=CC=CC=C2)N=CN=C1N',
#  'CC(C)(C)C1=NNC=C1N',
#  'CCCC1CCCCN1S(=O)(=O)C1=CC=CC=C1F',
#  'C=CCCCOCCO',
#  'COCC1=CC(=O)NC(CSC2=NN=C(N)N2C(C)C)=N1',
#  'COC1=CC=C(Cl)C=C1C(=O)N1CCC(C2=CC=CS2)CC1',
#  'CC1=CN=CC(C(=O)NC2CCC(SC3=CC=CC=C3)C2)=C1',
#  'CC1=CC=C(C2=CC(C(=O)N3CCC(N4C=CC(C)C4)S3)=N2)N=N1',
#  'COC1=CC=C(CN(C)C(=O)CC2N=C(N)NC3=NC(=O)CC(C)=C32)C=C1',
#  'CC(C)(C)OC(=O)N1CCCC1C1=NC(C2=CC=CC=C2)=NO1',
#  'CC(C)(C)OC1=CC=C(CC2=NN=C3COCC3=N2)C=C1',
#  'COC1=CC=C(OC)C(S(=O)(=O)N2CC(O)C([NH+]3CCCCC3)C2)=C1',
#  'CC(C(=O)NOCC1=CC=CC=C1F)S(=O)(=O)C1=CC=C(F)C=C1',
#  'CC([NH2+]CC1=CC=C(C(C)(C)C)C=C1)C1=CC=CN1C',
#  'COC1=CC=CC(OCCC(=O)N(C)C)=C1N',
#  'CN1C(CN2CCN(CC3=CC=CC=C3)CC2)=NC2=CC=CC=C2C1=O',
#  'CC1(C)CCCC2(C)N=NC=C21',
#  'CCOC1=CC=C(C2SCCCN(C(=O)CC3=CC=CC=C3)C2)C=N1',
#  'COC1=CC=C(NC(=O)C2CCCN2S(=O)(=O)C2=C(C)C=C(C)C=C2C)C=C1C',
#  'CC1=CC=C(O)C(C(C)(C)C2CCC([NH3+])C2)=C1',
#  'CC(CN(C)C1=CC=C(S(C)(=O)=O)C=C1)C1=CC=CC(Cl)=C1',
#  'COCC(NC(=O)C1=CN(C(C)(C)C)N=C1C1=CC=CC=C1F)C1CC1',
#  'CC1CN(C(CO)COC2=CC=CC=C2F)CC(C)O1',
#  'CC(C)N(CC1=CC=C(C(F)(F)F)C=C1)C(=O)C1CC[NH+](CC2=CC=CC=C2)CC1',
#  'COC1=NN=C(S(C)=O)C(C2=CC=C(Cl)N=C2)=N1',
#  'CC1CCCCS1C1=CC=CC=N1',
#  'COC1=CC=CC(C2=NN=C(NC(=O)C3=CC=CN=C3C)S2)=C1C',
#  'CC1=CC=C(NC(=O)C2=C3CCCCC3=NN2)C(C)=C1',
#  'CN1C(COC2=CC=C(Cl)C=C2)=NN=C1SCC(=O)N1CCSCC1',
#  'O=C(CCCOC1=CC=CC=C1Cl)N1CCOCC1',
#  'CC(C)C(C#N)S(=O)(=O)CC1=C(Cl)N(C)C=N1',
#  'COC1=CC=CC2=C1OC(C(=O)NCCC1=NC=CN1)C2',
#  'CC1=CC(C(=O)NC2CCCCC2C2=CC=NC=C2)=CC(S(N)(=O)=O)=C1N',
#  'CC1=CSC(CNC(=O)C2CCC([NH3+])C2)=N1',
#  'CC1=NN(C2=CC=C(Cl)C=C2)C=C1C(N)=S',
#  'CC(C)N1C(CN2CCN(C(=O)CCC(=O)NC4(CC)CCC3)CC2)=NN=C1C1CC1',
#  'COC1=CC=C(F)C=C1S(=O)(=O)NC1CC[NH+](CC2CCCCC2O)OC1',
#  'CCN1C(=O)SC(=NC2=CC=CC=C2)C1C1=CC=CC=C1',
#  'CC1=NN(C2=CC=C(NC(=O)NC3=CN=CC=C3C)C=C2)C(C)=C1',
#  'COC(=O)C1C[NH+](C(CNC(C)=O)C2=CC=C(F)C=C2)CC1C',
#  'O=C(NC(CO)C1=CC=CC=C1)C1CCCC2=CC(OC(F)(F)F)=C(Cl)C=C21',
#  'COC1=CC(C(C)NC(C)C2=NC3=CC=CN=C3N2)=CC=C1N1CCCCC1',
#  'CSCCCS(=O)(=O)N1CCN(CC2=CC=C(S(C)(=O)=O)C(Cl)=C2)CC1',
#  'O=C1NC(=CC2=CC=C(C3=CC=C(Cl)C=C3)O2)C(=O)N1C1=CC=CC=C1',
#  'CCC1=CC(N)=NC(C2[NH+]=C3C=CC(Cl)=CC3=N2)=N1',
#  'CC1=NC(C=CC(=O)N2CCN(C3=C(F)C=CC=C3F)CC2)=CS1',
#  'NC(=O)C1CN(C(=O)NC2=CC=C(Br)C=C2)CCO1',
#  'COC1=CC=C(NC(=O)CSC(C)C(=O)NC2=CC=C3C(C)=NN(C4CCCC4)C3=N2)C=C1',
#  'COC1=C(C(=O)N(C)CC2=CN3C=CC=CC3=[NH+]2)C(C2=CC=C(F)C=C2)=CN1',
#  'O=C([O-])CCC(=O)NC1CC[NH+](CC2CCCO2)O1',
#  'CN(CC1CCC1)S(=O)(=O)C1=CC=CC(C(N)=O)=C1',
#  'O=C(CSC1=NC([O-])=C(C2=CC=CC=C2)C(=O)O1)NC1=CC(Cl)=CC=C1Cl',
#  'NC1=CC=C(NC(=O)C(=O)NC2CCCCC2)C=N1',
#  'O=C1CN(C(=O)CN2CCCCCC2=O)CCS1',
#  'CC(C(=O)NC1=C(F)C=C(F)C=C1F)[NH+]1CCCCCC1',
#  'CCC(C)N1N=CC(C(=O)NC2=CC=C(OC(C)(C)C)C=C2)=C1C1CC1',
#  'CC1=CC(CC(=O)N2CCCC(C(C)O)C2)=NO1',
#  'COC1=CC=C(C2=C([O-])NC3=NN=NN3C2(C)CCCO1',
#  'CC(NC(=O)NCCN1C=C(C(F)(F)F)N=C1)C1=CC=CC=C1',
#  'CC(=NNC(=O)CC1=CC=CS1)C1=CC=CC(Cl)=C1',
#  'CCCC(=O)N1CCCC(C(=O)N2CC(O)C3=CC=CC=C32)C1',
#  'CC1=NN2C(=O)C=C(CN(C)C(=O)C3=CC=C([N+](=O)[O-])N3C3=CC=C(C)C=C3)C=NC2=C1',
#  'CCOC1=CC=C(NC(=O)CC2SC3=CC(OC)=CC=C3S(=O)(=O)N2)C=N1',
#  'CC(C)CCNC(=O)C1=CNC2=NC=CC(Cl)=C12',
#  'CC(C)OC1=CC=CC=C1NC(=O)C1CC(=O)N(C2=CC=C(Cl)S2)C1',
#  'CC1=CC=CC=C1C(CCN1CC[NH+]2CCCCC21)OC(C)C',
#  'N#CC1=C(S(=O)(=O)[O-])N2C(=O)C(=NNC(=O)C3=CC=CC=C3)N=C2N1',
#  'CC1=CC=CC=C1NC(=O)C[NH+]1CCN2N=C3C=C(C)C=CC3=C2C1',
#  'CC1=CC(C)=C(C)C(S(=O)(=O)NC(C)C2=NN=CN2C)=C1C',
#  'CC1=CC=C(C2NC3=CC=CC=C3C(=O)N2C)C=C1',
#  'C[NH+](C)CC1CCCCC1OC1=CC=C(NC(=O)NC2CC2C)C=C1',
#  'CC1COC(CC2=CC=CS2)NS1(=O)=O',
#  'CC(C)(C)C=CCCOC(=O)CNC(=O)C1=CC=C(F)C=C1F',
#  'COCC1=NC(C)=CC(SCC(N)=O)=N1',
#  'COC1CCC2=C(C1)SC(NS(=O)(=O)C1=C(C)ON=C1C)=C2C',
#  'CC1CC[NH+](C(CNC(=O)NCC(=O)[O-])C2CC2)CC(C)O1',
#  'CC1=CC=CC(N2CCN(C(=O)CN3C(=O)OCC3=O)CC2)=C1',
#  'CC1COC2=CC=C(NC(=O)C3=COC=C3)C=C2N=C1Cl',
#  'C[NH+](CC1=CC=C2C=CC=CC2=N1)C1CC[NH+](CC2=CN(C3=CC=CC=C3)N=C2)CC1',
#  'CC1=CC(CC2=CN=C(Cl)S2)=NC(N2CCN(C)CC2)=N1',
#  'COC1=CC=CC=C1N1CCN(C(=O)C2=NN(C3=NC=CC(C(F)(F)F)=C3)C=C2)CC1',
#  'CC(C1=CC=C(F)C(Cl)=C1)N1CCN(CC2=NNC(=O)N2)CC1',
#  'O=C(NC1CCC(O)CC1)C1=CC=C(Cl)N=C1',
#  'COC(=O)C1CC1C(=O)N1CCC(C2=NC(C)=C(C(=O)NC3CC3)O2)CC1',
#  'COC1=CC=C(C2[NH+]=C(N)NC3=C2C(=O)C2=CC=CC=C23)C=C1',
#  'COCCC(=O)N1CCC(C2=NC(C)=CC=C2C(N)=O)CC1',
#  'CCN1C(SCC(=O)NC2CCCCC2)=NN=C1C1=CNC=C1',
#  'CCN(C1=CC=CC=C1)S(=O)(=O)C1=CNC(C(=O)[O-])=C1',
#  'CCOC(=O)C1C2N=C(C)CN2C(C2=CC=C(OC)C=C2)=C1C',
#  'CCOC1=CC=C(OC)C=C1C[NH2+]C1CC1',
#  'COC1=CC(F)=CC(CNC(=O)NC2CCN(C(=O)OC(C)(C)C)C2)=C1',
#  'O=[N+]([O-])C1=CC=CC(C2CCCN2C(=O)NC2=CC=C(OC3=NC=CS3)C=C2)=C1',
#  'CCC(NC(=O)N(C)C(C)C1=CC=C(N(C)C)C=C1[N+](=O)[O-])C1=CC=CC=C1',
#  'CC(C)=CC1C(C(=O)[O-])C1C',
#  'COC1=CC=C([N+](=O)[O-])C=C1NC(=O)CN1C(=O)C(C)C2=CC3=C(C=C21)OCO3',
#  'NC(=O)C1=CC=C(NC(=O)CSCC2=CC=CC=C2F)C(F)=C1',
#  'CC(=NNC(=O)C1C=C(C2=CC=CC=C2)N=N1)C1=CC=CC=C1',
#  'CN(C)C=C1S(=O)(=O)C2=CC(Br)=CC=C21',
#  'O=C(NC1=CC=C2OCOC2=C1)C1CCCN1C1=NS(=O)(=O)C2=CC=CC=C12',
#  'COC1=CC=CC=C1C(=O)NC(=S)NNC(=O)C1=CC=CC=C1Br',
#  'CC1=CC=C(C2=CC=C(CNS(=O)(=O)C3=CC=C4NC(=O)CCCC4=C3)C=C2)C=C1',
#  'NC1=NC2=CC(C3CCCCC3O)=NN=C2C=C1',
#  'COCC1CCCN(C(=O)C(=O)NC2=CC=C3CC(C)CC3=C2)C1',
#  'CC(SC1=NC(C2=CC=C([N+](=O)[O-])C=C2)=CC(C(F)(F)F)=N1)C(=O)N1CCOCC1',
#  'NC(CCC1CCCC1)=[NH+]CC(O)CC(CO)C1=CC=CC=C1',
#  'COC1=CC=CC(C2C3=C(CC(C)(C)CC3=O)NC3=NC(C(F)(F)F)=NN32)=C1OC',
#  'CCC1=CC=CC(S(=O)(=O)NC)=C1C(F)(F)F',
#  'CC[NH+](CC)CC(=O)N1CCN(CC(=O)NC2=NOC(C)=C2)CC1',
#  'COC(=O)C(C)CN(C)C(=O)C1=CC2=C(C=NN2C)C2=CC=CN12',
#  'CC(C)CCNC1=NC2=CC=C(Br)C=C2S1',
#  'CCCC(O)CN(CC)C1CC1)C(=O)[O-]',
#  'CCCCN1C(N)=NC2=C1N(CC)N=C2[N-]',
#  'CC(C)C1=CC=C(CN(C(=O)C2CCS(=O)(=O)C2)C(F)F)C=C1',
#  'C(=C1CCC2=CC=CC=C2C1=O)C1=CC=C(Cl)C=C1',
#  'CC1=NN(C2=CC=CC=C2)C(NC(=O)CC2=C(C)N(C)C(=O)N(C)C2=O)=C1C',
#  'CCOC1=CC=C(C2C3=C(OC4=CC=CC=C4C3=O)C(=O)N2CCO)C=C1',
#  'CC1=C(C(=O)NCC2=CC=CC=C2Cl)C2=CC=CC=C2N1CC1=CC=CC=C1',
#  'COC1=CC=CC(C2=NOC(COCC(=O)NC3=C(C)C=CC=C3NC(=O)C3=CC=CC=C3)=N2)=C1',
#  'CSC(C(=O)NC1=CC=C(C)C(C)=C1)C1=CC=NC=C1',
#  'CC1=CC=C(CN(C(=O)NCC2=CC=NC(OC(C)(C)C)=C2)C2CC2)C=C1C',
#  'CCCOCC1(C(=O)[O-])CCC[NH+](CC)C1',
#  'O=C(NCC1=CC=C(O)C(O)=C1)C(=O)NC1=CC=C2OC(=O)NC2=C1',
#  'C=CCN1C(=O)C2=CC=CC=C2N2C(SCC(=O)C3=CC=C(Cl)C=C3)=NN=C12',
#  'CC(C)NC(=O)NC(=O)C(C)SC1=NC2=CC=CC=C2N1',
#  'CC1=CC=C(C(C)C)C(OCC(=O)N2CCCC3CCCCC32)=C1',
#  'COC1=CC=CC(S(=O)(=O)N2CCC(CN(C)S(=O)(=O)N3CCCCCC3)CC2)=C1',
#  'CCSC1=CC=C(C(O)CNC(C)=O)C=C1',
#  'CC1=NC(CC[NH2+]CC2=CC(C#N)=CS2)=CS1',
#  'COC1=CC=C2OC(CN3CCC([NH3+])C3)=NC2=C1',
#  'CC1(C)CSCC(NS(=O)(=O)C2=CC(O)=CC=C2Cl)C1',
#  'CC(=O)NC1=CC=CC=C1OC1=NC=NC2=C1CCC1=CC=C(C)C=C12',
#  'COC1=CC=CC=C1N1CCC(NC2CC[NH+](CC3=CC=CC=C3)C2)CC1',
#  'CCC1=NC(CC(=O)NC2(C#N)CCCCCC2)=CS1',
#  'COCC(NC(=O)C1CCC(C[NH3+])O1)C1=CC=CC=C1C',
#  'CC[NH2+]C(C1=CC=C(C)C=C1C)C(C)C1=CC=NC=C1',
#  'CCCC(C)C1=NN=C(NC(=O)C2=CC(OC(=O)CCC)=CC2=CN(C)S(=O)=C1',
#  'O=C(COC1=CC=CC=C1Br)NCC1CCC(C(N)=O)O1',
#  'CC(CSC1=CC=CC=C1)NC(=O)NC1=CC=C(C(N)=O)C=C1',
#  'CC1(C)CC(C2=NN=C([S-])S2)C(O)C1O',
#  'CC1=CC=CC=C1C1CC1NC(=O)NC(C)C1=CC=C(OC(F)F)C=C1',
#  'C[NH+](CCNC(=O)N1CCCCCC1)C1CCCC1',
#  'COC1=CC=CC=C1N1CC[NH+](CC2(CS(C)(=O)=O)CC2)CCO1',
#  'COC1=CC=C(C2CC(C3=CC=CC=C3)=NN2C(=O)CCC(C)(C)C)N=C1',
#  'N#CC1=C(N)OC2=C(C(C3=CC=CS3)=NO2)C1C1=COC2=C1CCC2',
#  'O=C(CCC(=O)N1CCC1)NC1CCCCCC1',
#  'CC(=O)C1=C(C)NC(C(=O)NNC(=O)C2=CC=C(C)N=C2Cl)=C1C',
#  'CC1CCCCN1C(=O)C(C)OCC1CCCCO1',
#  'C=CCNC(=O)N(CC1CCCCO1)C(C)C',
#  'CC1=NOC(C(C)C)=C1COC1=CC=CC=C1C1CC1',
#  'CC1=CC(C)=C(C=C2OC3=C4C(=O)N=C(N)[NH+]=CC=C4N3)C(=O)N2C2NC(=O)NC2=C1',
#  'CC1=CC=C(NC(=O)CSC2=NN=C(C)N2CC(=O)N2CCN(C3=NC=CS3)CC2)C=C1C',
#  'CC(=O)NC1=CC=CC(NC(=O)C2=NN(C3=CC(Cl)=CC(Br)=C3)C(=O)C=C2)=C1',
#  'O=C(COC1=CC=CC=C1[N+](=O)[O-])N(CCN1CCOCC1)C1CCS(=O)(=O)C1',
#  'CC1=C(NC(=O)CCS(=O)(=O)C2=CC=CC=C2Cl)C=CC=C1[N+](=O)[O-]',
#  'CCCN1C=C[NH+]=C1CN1CC(C)C(C)C1',
#  'CCCNC1(C#N)CCCCC1(O)CC',
#  'CC(OC1=CC=CC=C1C#N)C(=O)OCCC[NH+]1CCCC1',
#  'CC1=C(C(NC(=O)N2CCC([NH+]3CCCC3)CS(=O)(=O)N2)C2CCCO2)C=CC=C1[N+](=O)[O-]',
#  'CC1(NC(=O)CSCC(=O)NC2=CC=CC(F)=C2)CCCS1(=O)=O',
#  'CC(OC(=O)C1CCOC1C)C1=NC2=CC=CC=C2N1CC(O)COC1CCCCC1',
#  'CCOC1=CC=CC(C(CC(C)N#C2CC2)[NH+](C)C)=C1',
#  'C[NH+]1CSCC1C(=O)NC1=CC(C2CCCCC2)=NN1C1=CC=CC=C1',
#  'CC1=CC=C2C=C(C[NH+]3CCC(NC(=O)NC4=CC=CC=C4)C3)CC2=C1',
#  'CC[NH+](CCNC(=O)C(C)NC(C)=O)C1CCS(=O)(=O)C1',
#  'CCOCCN(C)C(=O)NC1=CC=C(C)C(S(C)(=O)=O)=C1',
#  'CN1N=C(CCNC(=O)C2CC3=CC(Cl)=C(O)C=C3C2)C=CC1=O',
#  'CC(=O)C1=C(C)NC(C(=O)NC2=CC=C(C(=O)NC(C)(C)C)C=C2)=C1C',
#  'CC(=O)NC1CCCN(C(=O)NCC(C2=CC=CO2)[NH+]2CC(C)CC(C)C2)C1',
#  'CC1=C(C(=O)NC2CC[NH+]3CCCC23)SC=C1',
#  'CC(C)CNC(=O)C(=O)NC1=CC=CC(OCC2=CC=CC=N2)=C1',
#  'CC1=CSC2=NC(C3=CC(OCC(F)(F)F)=CC(C4=NC(C)=CN4)=N3)=CC=C21',
#  'CC[NH2+]C1C(C[NH+]2CCCCC2)SC(C(=O)N(C)C)C1C',
#  'COCC1=CC=C(C[NH2+]C(C)C2=CC=C(C)C=C2F)C=C1',
#  'CC1=C(C(=O)NC2=CN=C(N3CCN(C4=CC=CC=C4C)CC3)S2)OC=C1',
#  'O=C([O-])C1=CC=C(S(=O)(=O)NC(C2=CC=CC=C2)C2=CC=CC=N2)C=C1',
#  'COC1=CC=C(CNC(=O)C2=CC=C(S(=O)(=O)N3CCC4=CC=CC=C43)C=C2)C=C1',
#  'CCC(C(=O)NC1=CC=CC(F)=C1)NC(=O)C1=CN(C)N=C1C(C)C',
#  'CC1(C)CN(CC2=NC3=CC=CC=C3O2)CCO1',
#  'CC1=CC=CC2=C1N=CN(S(=O)(=O)C1=C(F)C=CC=C1Br)CC2',
#  'CC1CC(=O)N(CCCC(=O)N2CCN(C3=CC=CC=[NH+]3)CC2)C(C)=[NH+]1',
#  'CCS(=O)(=O)N1CCC2(CCCN(CC[NH+](C)C)C2=O)C1',
#  'CC1=C(C)S(=O)(=O)C2=CC3=C(C=C2O1)OCCO3',
#  'CC1=CC=CC(S(=O)(=O)N=C([O-])COC2CCCC2=O)=C1C',
#  'O=C(NC1CCCCC1)N1CC3C[NH+]3CCC1C1',
#  'CCCN(CCC)C(=O)C1=CC=C(OC)C2=NC=CC=C12',
#  'C1=CC(C[NH2+]CC2=CC=C(Br)S2)=CC=C1Br',
#  'COC1=CC=C(S(=O)(=O)N(C(=O)[O-])C2CCOC2C)C=C1',
#  'CC(NC1=NN2C(C3=CC=CC=C3)=NN=N1)=CN2C1=CC=CC=C1',
#  'NC(=O)C1CCCN(C(=O)C(C2=CC=CC(O)=C2)C2=CC=CC=C2)C1',
#  'COC1=CC=C(C(C[NH3+])N2CC(C[NH+]3CCCCC3)C2)C=C1OC',
#  'COC1=CC=C(S(N)(=O)=O)C=C1C(=O)N(C(C)C)CC(C)C',
#  'CC1=CC=C(NC(=O)C(N)C(F)(F)F)C=C1C(F)(F)F',
#  'CC1CCN(C(=O)NCC2=C(Cl)C=NN2C)C2=NC3=C(C=N2)OC=N1',
#  'N#CCC1=CC=CC(CNC(=O)NC2=CC=CC=C2N2CCCC2)=C1',
#  'CN(CC(N)=O)C1=NN=C(C2=CC=NC=C2)S1',
#  'CCC(CSC)N(C)C(=O)NC1=CC=CC=C1Cl',
#  'O=C(NC1CCCCC1)N1CCC(NC2=CC(F)=CC3=CC=CC=C23)CC1',
#  'CC1=NN(CC(C)C)N=C1C(=O)NC1CCN(C2=CC=CC(F)=C2)CC1',
#  'COC1=CC=CC(C2=CCN(C(=O)C3CC3)CC2C)=C1C',
#  'O=C(NCC1=CC=CC=C1)NC=CC(=O)NC1=NC(C2=CC=CO2)=CS1',
#  'COC1=CC=C(NC2=NN=C(SC(C)C#N)S2)C=C1',
#  'O=C1CCCC1CC1=CC=CC=C1',
#  'CC(C)(C)OC(=O)NCC1=CC(Cl)=CC=C1[N+](=O)[O-]',
#  'CC1=CC=C(C2=NNC(SCC3=CC(=O)N4C=CC=CC4=N3)=N2)C=C1',
#  'CC1=C(C)NC2=C(C3=C(CCCCC3)S2)C1C',
#  'CC1(C(=O)NCC2CCCO2)=NC2=C(C3=C(CCCC3)S2)C1=O',
#  'CCC1=CC=C(CN2C(=O)COC3=CC=C(S(=O)(=O)N4CCC3)C=C23)C=C1Cl',
#  'COC1=CC(C(=O)N2CC(C)CC(C)C2)=CC(OC)=C1OC',
#  'FC1=CC=CC=C1C1=CC=NC(NN)N1',
#  'COC1(C)CC(NC(=O)C2=CC=CN=C2SC2=CC=CC=C2Cl)C1(C)C',
#  'C[NH+]1CCCCC1C(=O)N1CCC(CNC(=O)C2=CC=CO2)CC1',
#  'CC(=O)NC1=CC=CC=C1CN1CCN(C(=O)CCS(C)(=O)=O)CC1',
#  'CC1=CC(C)=CC(NC(=O)NC(C)CO)=C1',
#  'COC1CC[NH+](C(CSC)C(=O)[O-])CC1',
#  'O=C(NCC1(O)CCCC1)C1=C(CSC2=NC=NC3=NC=NN23)NC2=CC=CC=C12',
#  'CC(C)OC1=CC=C(CC(=O)NC2=CC(C(N)=O)=CN=C2N(C)C)C=C1',
#  'O=S(=O)(CCCF)C1=CC=CC=N1',
#  'CCOC1=NC=CC=C1C[NH2+]CC1(CC(C)C)CC1',
#  'CC1=CC=C(OCCSC2=NN=C(C3=CN(C)N=C3C)[N+](2)C(=O)NC2=CC=CC=C2Cl)C=C1',
#  'COC1=CC=CC=C1C(C#N)NC(=S)NC1=CC=CC(C#N)=C1',
#  'CC1=CC=C(C)N1C1=CC=C(C(=O)NC2=NN=C(CC3=CC=CC(F)=C3)O2)C=C1',
#  'CC1C(C(=O)[O-])CCN1C(=O)NC1CCSC2=C(F)C=C(F)C(F)=C21',
#  'COC1=NC(C)=CC(C)=C1NC(=O)NCC1=CC=NC=C1',
#  'C=CCOC1=C(C=CC2=CC=C(C)C=C2)C(C(C)C)=C(C)S1',
#  'C#CCSC1N=C(SC)N=CN1CC',
#  'CCNC(=O)C1=CC=C(CNC(=O)NC2CCCC2SC)C=C1',
#  'COC1=C(C(=O)NC2=C(C#N)N=CS2)SC=C1',
#  'CC1=CN2C(=O)C(C(=O)NC3=NN=C(C(F)(F)F)N3N=CC3=CC=CC=C3)=CN=C2S1',
#  'CC1=CC(F)=CC=C1NC(=O)C(=O)NCC1=CC=CC=C1OC1CCCC1',
#  'CC(CNC1=NN=C(C2=CC=C(S(=O)(=O)N3CCCCC3)N=C2)N1C)C1=CC=CC=C1',
#  'CC1=NOC(C(C)OC2=CC=C3N=CC=CC3=C2)=N1',
#  'CC1CCC[NH+](C(C)C(=O)N2CC(C)OC(C)C2)C1',
#  'O=C(NC1=CN(CCC2=CNC=[NH+]2)S1)N1CCCC(COC2=CC=CC=C2)C1',
#  'COC1=CC=CC=C1N(CC[NH+](C)C)C1=NC=C(C2=CC=C(Cl)C=C2Cl)O1',
#  'CC(C)CC(=O)NCCNC(=O)NCC(C1=CC=CO1)N1CCOCC1',
#  'COC1=CC=C(C(=O)NCC2=NC(C(F)(F)F)=CS2)C(OC)=C1',
#  'CC1=CC=C(C2=NNC(C(=O)NC3=CC=CC=C3N(C)C)=C3N=CC3=CC=CC=C23)C=C1',
#  'CC1=NN=C(SC(C)C2=NC=C(C(C)(C)C)C(C)N2N)C(=O)N1',
#  'COC1=CC(OC)=C(CN2CCOCC2CCl)C([N+](=O)[O-])=C1',
#  'CCC(C)NC(=O)N1CCCC(CC2=NN3NC(=O)C4=CC=CC=C4C3=N2)C1',
#  'CC1=CC=CC(OCCNC(=O)CN2N=C(C)C=C(C)N2)=C1',
#  'COC1=CC=C(C(NC(C)C2=NC(C)=CC(C)=N2)C(C)C)C=C1',
#  'COC1=CC=C(C2NC(=O)NC(C3=CC=C(OC)C=C3)O2)C=C1',
#  'CC1=CSC(CC(C)(C)O)=N1',
#  'COC1=CC=C(C2=CC(C(=O)N3CCC(CN4C=NN=N4)CC3)=NO2)C=C1',
#  'CSCC(CCO)CNC(=O)CN1C=C(Br)C=N1',
#  'COC1=CC=CC=C1C1=CSC(NC(=O)C2=CC(N)=CC=C2Cl)=N1',
#  'COCC1=CC(C(=O)NCC(C)(C)[NH2+]C2CCCCC2CO)=NN1',
#  'C[NH2+]C1C2=CC=CC=C2CC1O',
#  'CC1CCCC[NH+]1CCCOC1=CC=CC=C1',
#  'O=C(NC1CCCC2=CC=CC=C21)N1CCN(C2=NC=CC=C2C#N)CC1',
#  'COC1=CC=CC(CC(NC(=O)CC(C)(C)C)C2=CC=CS2)=N1',
#  'CC(C)(C)C1=CC=C(S(=O)(=O)N2CCOCC2)C=C1C(=O)NCC1=CC=CN=C1',
#  'CC1CC(C(=O)NC2=CC=C3OC(=O)OC3=C2)CCO1',
#  'CCC(C)C(=O)OC1C(C#N)=C(N)OC2=CC(Br)=CC=C21',
#  'CC1CCC2=NNC=C2CC1C(=O)[O-]',
#  'COC1=CC=C(C(C)(O)CNC(=O)C2CCC(C[NH3+])O2)C=C1',
#  'NC1=NN=C(SCC(=O)NC2=CC=CC=C2)N1CC1=CC=CN=C1',
#  'CCCNC(=O)COC1=CC=C(Br)C=C1C(N)=S',
#  'CC(O)C(C)SCC1=NN=C(CC2=CC=C([N+](=O)[O-])O2)O1',
#  'CC1CN(S(=O)(=O)C2=CC=C(C(=O)NCCC3=CC=CC=C3)C=C2)CC(C)O1',
#  'CC12CCC3(C)C(CC3=CC(O)=C(C)C=C3O1)C2C(=O)OCC1CCCO1',
#  'O=C1CCCC1N1CCN(CC(=O)N2CCCC3=C2C=NN3C2=CC=CC=C2)CC1',
#  'CC(O)C1CCC[NH+](CCOC2=CC=C(CC#N)C=C2)C1',
#  'CC(C)(CO)NC(=O)CNC(C1=CC=CS1)C1CCCC1',
#  'CNC1(C#N)CCC(N2CC[NH+](C)CC2)C1',
#  'CC(C[NH+]1CCN(C2=NN3C=CC=CC3=N2)CC1)[NH2+]CC1=CC=CC=C1',
#  'COC(=O)C(C)C(NC1=CC=CC=C1)C(=O)NC(C)C1=CC=CC=C1',
#  'CC1CN(CC2=CC=CC=C2F)C(C)SC1',
#  'N#CC1(NC(=O)C2=C(COC3=CC=C(F)C=C3)C=CC=C2C2=CC=CC=C2)CCCC1',
#  'CC1=CC=C(S(=O)(=O)[N-]C2=CC=CC(OCC(N)=O)=C2)C(C)=C1',
#  'O=C(NC(=S)NC1=CC=C(C2=CC=CC=C2)C=C1)C1CCCO1',
#  'CCS(=O)CCCN(C)C(=O)NC1=CC=CC2=C1C(=O)N(C)N=C12',
#  'CCCOC1CCC[NH+](CC2=CC=[NH+]C=C2C2CCCCC2)C1',
#  'CNC(=O)COC1=CC(CNC(=O)NC2C3=CC=C(F)C=C3CC2C)=CC=C1F',
#  'O=C(CC1=CC=CC(F)=C1)NNC(=O)C1=CC=CN=C1',
#  'O=S(=O)(NCCCC[NH+]1CCCC1)C1=CC=C(Cl)S1',
#  'CCC(CSC)[NH+](C)CC1=NC(C2=CC=C(C)C=C2)=NO1',
#  'CC1=C(C[NH+](C)C2CCN(CC3=CC=CC=C3)CC2)OC2=CC=CC=C12',
#  'COC1=CC=C(C(CNC(=O)C2=C(C)C3=CC(C)=CC=C3N2)N2CCOCC2)C=C1',
#  'COC1=CC=C([N+](=O)[O-])C(C2=CSC(C)=N2)=N1',
#  'CC1=CC(N(C)C)=CC=C1NC(=O)CC1C(=O)NC(C)(C)C1(O)CC',
#  'O=C(CC(O)C1=CC=CC=C1)NN1CCCCCCC1',
#  'CC1=CC([N+](=O)[O-])=CC=C1NC(=O)CCC1=C(C)NC(=O)C2=CC(Cl)=CC=C21',
#  'CCC(C)(NC(=O)NC1=NC=CS1)C(=O)[O-]',
#  'COC1=CC=CC=C1S(C)(=O)=O',
#  'O=C(NC1=CC=CC(Br)=C1)C1CC1C1=CC=CC2=C1OCO2',
#  'O=C(CSC1=NN(C2=CC=CC=C2)C2=C1CCC1=CC=CC=C12)N1CCCC1',
#  'CN(CC(F)(F)F)C(=O)C(C#N)=CC1=CC=C(N2CCOCC2)C=C1',
#  'O=C(NCC1=CC=C(F)C=C1)C1=CN(CC2=CC(=O)N(C3=CC=CC=C3)N=C2)C=N1',
#  'COC1=CC2=C(C=C1OC)CN(C(=O)CCCNC(=O)C(C)C)C(C)CC(=O)NC2C',
#  'CCN(C(=O)C1CC1(C(=O)C1=CC=CC=C1)C1CC1)C1=CC=CC=C1',
#  'CC1=CC=C(NC(=O)C=CC2=CC=C(N(C)C)C=C2)C(C)=C1',
#  'CC(C)C(SC1=NN=CN1C1=CC=CC=C1)C(=O)NC1=NC=CS1',
#  'CC1=C(C)N(CC2(C3=CC=CN=C3)CC2)C(=O)NC1C1=CC=C([N+](=O)[O-])C=C1',
#  'CC1=CC=C(C(NC(=O)C(=O)NC2=CC=CC=C2)C(C)C)C=C1',
#  'CC(C1=CC=CC=C1)N1CCN(CC2CCCO2)C(=O)C1',
#  'CC(=O)NC1(C(=O)C2=CC=CC(C)=C2)CCCC1',
#  'CCN(C1CCS(=O)(=O)C1)S(=O)(=O)N1CCN(CC2=CC=CC(F)=C2)CC1',
#  'CCOC1=CC=C(C2=NOC(CN3CC[NH+](CCNC(C)=O)CC3)=N2)C=C1',
#  'CCOC(=O)C1=CC=C(NNC(=O)CS(=O)(=O)C2=CC=CC=C2)C=C1',
#  'CC(=O)C1=CC=C(NC(=O)C(=O)NCC2=NOC(C3=CC=C(F)C=C3)=C2)C=C1',
#  'CC1COCC(C[NH2+]C2CCC3=CC=CN=C32)C1',
#  'COC(=O)C(C)NC(=O)CN1C(CCCl)=NC2=CC(F)=C(Cl)C=C21',
#  'CC(C)(CC1=C(Cl)C=CC2=CC=CN=C12)NC(=O)C1CCC1',
#  'COC1=CC2=C(OC(F)(F)C(O)C2O)C=C1Cl',
#  'CC1C[NH+]2CCCC2CN1S(=O)(=O)C1=CC(F)=CC=C1N1C=NC=N1',
#  'O=C1CCCCC1OC1CCCCC1O',
#  'CC1=NNC(C)=C1CCC(=O)NCCC1=CNC2=CC=CC=C12',
#  'COC1=NC2=CC=CC=C2N=C1SCC(=O)NC1=CC=CC=C1C',
#  'C#CCOC(=O)C1=C(O)C=C(N2CCOCC2)C(C(F)(F)F)=C1',
#  'O=C(CC1=CC=CC=C1)OCCC1=CN2C=CC=CC2=N1',
#  'CC1=CC=C(C(=O)NC2=CC=CC(C3=NNN=C3S)=C2)C=C1',
#  'CC1CC(C)C[NH+](CC(O)COC2CCCCC2)C1',
#  'COC1=CC=CC=C1C(C)NC(=O)C=CC1=CN(C2=CC=CC=C2)N=C1C',
#  'CC1=NC(C)=C(CNC(=O)NC(C)C(C)C)S1',
#  'CC(OC1=CC=CC(CO)=C1)C(=O)N1CCN(CC(=O)N2CCCCC2C)CC1',
#  'CCC1(C([NH2+]C)CC2=CC=C(F)C=C2)CCC[NH2+]C1',
#  'COC1=CC=C2C(C)=C(COC(=O)C3CCC(=O)N3)CCC2=C1',
#  'O=C(CSC1=NC(=O)N(C2=CC=CC=C2)C1=O)NC1=CC=CC=C1Cl',
#  'CN(CC1CCC1)CC([NH3+])C1=NC=CS1',
#  'C[N+]1(CCOC2=CC=CC(C=O)=C2)CCCCC1',
#  'CCN(C(=O)CN1C=C(CNC(=O)NC)C(C)=N1)C1CCCCC1',
#  'CS(=O)(=O)CC(=O)NC1=CC=CC(O)=C1',
#  'CC(C)CC(=O)NC1=CC=CC=N1',
#  'COCCCN1C=CC(NC(=O)C2C(CC3=NC4=CC(Cl)=C(C)C=C43)OC23)=N1',
#  'CC1=CSC(N2CCC[NH+](CC(=O)N3CCCCC(C)C3)CC2)=N1',
#  'CC([NH2+]C(C)C1=C(C)N(C2=CC=NC=C2)N=C1)C(C)C1=CC=CC=C1',
#  'CC(NC(=O)NC1=CC=CC=C1F)C1=CC=CC=N1',
#  'CSCC1=CC=C(CNC(=O)CC2CCC2)C=C1',
#  'O=C(NC(=S)NC1=CC=C(C(F)(F)F)C=C1)C1=CC=CC=N1',
#  'CCOC1=CC(NC2=CC=C(NC(=O)C3CCCN3C(=O)NC3=CC=CC=C3)C=[N+]2C)=CC=N1',
#  'O=C(C1=CC=CC=C1)N1CCC[NH+](CC2=CC=C(F)C=C2)CC1',
#  'CN1CCN(C(=O)C2=CC=C(O)C=C2)CC1O',
#  'CN(CC1=NN=C(C2CC2)[NH+]1C)C(=O)C1CCCCC1)C1=CC=NC=C1',
#  'O=C(NC1=CC=CC2=C1N=CN2)C1=CSC(C2=CC=C(Cl)C=C2)=C1',
#  'NC1=NON=C1NC(=O)C1=CC=C(S(N)(=O)=O)C=C1',
#  'C=C(C)C[NH+](C(C)C)CC1=CC=CC(C2CC2)=C1',
#  'O=C(NC1CCCCC1)SC1=CC=CC(NC(=O)C2=NN(CC3=CC=CC=C3)C(=O)C(Cl)=C2)=C1',
#  'CC1=CC=CC(N(C)C(=O)C(C)[NH+]2CCCCC2C(N)=O)=N1',
#  'COC1=CC=C(Cl)C=C1S(=O)(=O)N(C)CC1=CN2C(C)=CC=C1C2O',
#  'C[NH2+]C1C(S(=O)C2=CC=C(Br)C=C2)CCCO1',
#  'CC[NH2+]C(C(C)CC)C1CCOC2(CCCC2)C1',
#  'O=C1CN(C(=O)COC2=CC(Cl)=CC(Cl)=C2)CCN1',
#  'CCN(CC1=CC=C(S(C)=O)C=C1)C(=O)C1=C(C)C2=C(N=C3CCCCN32)S1',
#  'C[NH2+]C(C1=CC=CC=C1)C1=CC=CN1CC(=O)N(C)C1CCCCC1',
#  'CN1N=CC2=C1CCCCC2[NH2+]C1CCCCC1C1=NC2=CC=CC=C2S1',
#  'CN1C(C[NH3+])=[NH+]CC1C1=CC=CC=C1F',
#  'CC1=NNC(SCC(=O)NC2=CC=C(C(=O)NCC(N)=O)C=C2)=N1',
#  'CC(C(=O)N1CC2CCCCC2C1)N1C=NC2=C1C(=O)N(C)C(=O)N2C',
#  'CC1=NC(N2CCN(CC(=O)NC3CC3C)CC2)=C2C=NN(C3=CC=CC=C3)C2=N1',
#  'COC(=O)NC(CCOC1CCOC2=CC=C(F)C=C21)C1=CC=CO1',
#  'C[NH+]1CCCC1C1=NNC=C1NC(=O)C1=CC=C([N+](=O)[O-])C=C1',
#  'CCCNC(=O)CSC1=NN=C(C2CC2)N1C1=CC=CC=C1',
#  'CC1=NN2C(=N1)NC(SCC1=CC=CC(Cl)=C1)=CN2C',
#  'CC1C[NH+](CCN2CCOCC2)CC1C',
#  'CCC(NC(=O)C1=CC=CC=C1)C(=O)NC1=CC2=CC=CC=C2O1',
#  'COC1=CC=C(Br)C=C1C[NH2+]CC1(O)CCC2=CC=CN=C21',
#  'COC1=C(C(=O)NC2=NC=CC=C2COC)C2=CC=CC=C2S1',
#  'O=C(NCC1(C2=C(Cl)C=CC=C2Cl)CC1)C1CC1',
#  'C#CCOC1=CC=C2C=CC=CC2=C1CN1CCOCC1C1CC1',
#  'CC(C1=NOC(C2(C)OC3=CC=CC=C3C(=O)N2)=N1)N1CCOCC1C1CC1',
#  'CC(C)(C)OC1=CC(C(F)(F)F)=NC(CC[NH3+])=N2',
#  'CC1=CC(C)=C(O)C(C(CO)NC(=O)C2=CN(CC3=CC=CC=C3)N=C2)=C1',
#  'CC(=O)OC1CCN(C(=O)C2=CC=CC(C)=C2)CC1',
#  'CC1=CC=C(C(C)NC(=O)C2CCCN2C(=O)C2=C(F)C=CC=C2F)O1',
#  'CC1(C)OC(C)(C)C1[NH2+]C1CCN(C2=CC=CC=C2Cl)C1=O',
#  'CCC1=CC=C(N(CC(=O)[O-])C(=O)C(C#N)=C2C(C)CCCCC2)C=C1',
#  'CC(C)CC[NH+](C)CC1C(=O)NC2=CC=C(Cl)C=C21',
#  'C1=CC=C2C(=C1)N=CS2',
#  'CC1=NC(C(NC(=O)C2COCCO2)C2=CC=C(C#N)C=C2)=NC(C)=N1',
#  'COC1=CC=C(C)C2=C1N=C(N1CC(C)C(CO)C1C)N2CC',
#  'CCC(NS(=O)(=O)N1CCN(C2=NC=CC=C2C#N)CC1)C1=CC=CC=C1',
#  'CC1=CC(C(C)NC(=O)NC2CCC[NH+](C)CC2)=C(C)N1CC1=CC=CC=C1',
#  'CCCC1C(=O)NC(=O)CC1C1=CC2=C(C=CC3=CC=CC=C32)OC1=O',
#  'OCC1CNC(=S)N(C2=CC=C(Br)C=C2)C1C1=CC=C(Cl)C=C1',
#  'CCC(C)C(=O)N1CCCC(C2=NC(C)=CC(=O)N2CC)CC1',
#  'CC1(C2=CC=C(F)C=C2)OC(CO)(CC2=CNC3=CC=CC=C23)C1',
#  'CCC1=CC=C(C)C(C(=O)NC(C)C2=CC=C(C#N)C=C2)=C1',
#  'COC1=CC=C(NC(=O)N2CC(C)CC(C)C2)C=C1SC',
#  'CC(CNC(=O)C1=CC(N)=C(C)S1)NC1=C(F)C=CC=C1F',
#  'O=C(COC1=CC=C(Br)C(Cl)=C1)NC1=CC=C([N+](=O)[O-])C=C1',
#  'CC(C)CC(=O)N1CCC([NH2+]C2CCN(C(=O)CC3C=CCC3)CC2)CC1',
#  'COC(=O)C1=CC=C(NC(=O)CNC2=CC(C)=NC3=C(C)C(C(C)C)=NC3=C2)C=C1',
#  'CC(CO)CSC1=C([N+](=O)[O-])C=C(F)C=C1Br',
#  'CCC(NC(=O)C1CCC(=O)N1)C(C)(C)C1=CC=CC=C1',
#  'COC(=O)CC1CCCC[NH+]1CC1=CC(C(=O)N(C)C)=CS1',
#  'CC1=CC=C(C(=O)NC(C)(C)CC2=CNN=C2)N=C1',
#  'CCC(CS)COC1CCCCC1',
#  'CCCC(=O)N1CCCC1C1=NC2=CC(Cl)=CC=C2S1',
#  'COC(C)C(N)C=CC(=O)OC',
#  'O=CC1=CC2=CC=CC=C2C=C1NC1=NC=NC2=NC(C3=CC=CS3)=CC1=O',
#  'CC1CCC([NH3+])CC1CC(=O)NCC1CCCO1',
#  'CCC(OC1=CC=C(Cl)C=C1)C(=O)N1CCN(C(=O)C2COC3=CC=CC=C32)CC1',
#  'CC(O)C(=O)NC1=CC=C(S(=O)(=O)NC(C)C2CCCCC2)C=C1',
#  'O=C(NC1=CC=CC=C1F)C1CC[NH+](CC2=COC3=CC=CC=C23)CC1',
#  'COCCNS(=O)(=O)C1=CC=C(C2=CC=C(C(=O)[O-])C=C2Cl)C=C1',
#  'CC1=NN=C2C=CC(N3CCC(O)(C(C)C)C3)=NC2=N1',
#  'COC(=O)NCC(=O)NC1=CC=C(C(N)=O)C(C)=C1[N+](=O)[O-]',
#  'CC=C(C)C(=O)N1CCC2(CCCN(C)C2=O)C1',
#  'COC1=CC=C(C2CCC[NH+]2CC2=NOC(C3=CC=C(OC)C(OC)=C3)=N2)C=C1',
#  'COC1=CC=C2C(CC(=O)N3CCCN(C4=CC=C(F)C=C4)CC3)=CC(=O)OC2=C1',
#  'O=C(NC1=CC=CC=C1N1C=CN=C1)C1(C2=NC3=CC=CC=C3O2)CCOCC1',
#  'CCS(=O)(=O)CC(C)N(C)C(=O)C1CCCC2=CC=CC=C21',
#  'CCCC1CC(C)CCC1OCC(=O)C(C#N)C1=NN=CN1C',
#  'COCC(C)NC(=O)CC1=C(F)C=CC=C1F',
#  'CC1=CC=C(C(=O)NC2=CC=CC(C(=O)NC3C=C(C)C4=CC=CC=C34)=C2)S1',
#  'O=C(NC1=CC=C(N2NC(C3=CC=CC=C3)=N2)C(O)=C1)C1=C(Br)C(CSC2=NC3=CC=CC=C3O2)=NO1',
#  'COC1=CC=C(C2=NN(C)C=C2C(=O)NCCC2=C3C=CC=CC3=[NH+]C2=O)C=C1',
#  'CC(CC1=CC=CS1)N1C(=O)C(=CC2=CC=C3OCOC3=C2)SC1=S',
#  'O=S1(=O)CCC2(CCCC2)C1O',
#  'CC1=CC(C)=C(C)C(S(=O)(=O)NC(CCO)C2=CC=CC=C2)=C1C',
#  'CCOC(=O)C1NC2(C(Br)C(=O)N(C3=CC=CC=C3)C2=O)C1OC(C)(C)C',
#  'C1=CC(Br)=CC2=CC=NN12',
#  'CC1=CC=C(F)C2=NC(COC(=O)C3=CC=CC=C3)=CC(=O)N12',
#  'CC(O)CC1CCC[NH+]1CC1(O)CCCC1',
#  'COC1=CC(C)=CC=C1S(=O)(=O)N(C)C1=CC=C([O-])N=N1',
#  'CC(C)S(=O)(=O)C1=NN=C(S(=O)(=O)CCC(=O)N2CCCC2)N1CC1COC2=CC=CC=C2O1',
#  'CC(CNC(=O)N1CCC(O)C1)C1=CC=CC=C1Cl',
#  'CCN1N=C(C)C(S(=O)(=O)N2CCCN(C3=CC=CC(OC)=C3)CC2)=C1C',
#  'CC(CC1CC1)[NH2+]C1CCCCC1(C)C',
#  'CC1=NNC2=NC=C(C(=O)NCC(C)(N)C(C)(C)C)C(Cl)=C12',
#  'CC1=CC=C(C)C(OCC(O)C[NH+]2CCCCCC2C(N)=O)=C1',
#  'CCN(C(=O)C1=C(C)OC(C2=CC=CC=C2)=C1)C1CCCCC1',
#  'O=C([O-])CC1=NC2=CC=CN=C2N1C1CCCC1',
#  'CC(C)SC1=NC(C(F)(F)F)=NC2=CC=C(F)C=C12',
#  'COCC1=CC(C(=O)NC2CCCCC2O)=NC=N1',
#  'COC1=CC=CC(N2C(=O)NC(=N)C(C(=O)NCCC3=CCCCC3)=N2)=C1',
#  'CCCC1CN(CC2=CN=NN2C)CCO1',
#  'O=CC1=CN=C(C2=CC=C(C3=CC=NC=C3)O2)N=C1',
#  'CCC(=O)N1CCC(C2=CSC(NC(=O)COC3=CC=C4OCOC4=C3)=C2)CC1',
#  'CN(CCN(C)C(=O)NC(C)C1CCCO1)C(=O)OC(C)(C)C',
#  'CC1=C(CNC(=O)NC2CCCCC2O)OC2=CC=C(F)C=C12',
#  'CC1=CC=CN=C1N1CCC(OC2=CC=C(C#N)C=N2)CC1',
#  'CC(NC(=O)C1=CC=C2NC(C)=C(C(C)C)C2=C1)C1=CC=C(F)C=C1',
#  'CC1=NOC(C)=C1C(C)N(C)C(=O)CCCCN1N=NC(C2=CC=CC=C2)=N1',
#  'CC(NC(=O)C1(C2=CC=C(C(F)(F)F)C=C2)CC1)C1=CC=CC=C1',
#  'COC1=CC=C(C2C(C#N)=C(C)NC3=C2C(=O)NC(=O)N3C2=CC=C(C)C=C2)C=C1COC1=CC=CC=C1',
#  'CCS(=O)(=O)N(C)C(C[NH3+])CC(C)C',
#  'CCC[NH+]=CN(CC1=CC=C(OC)C=C1)C1=NC(CSC)=NC(C)=C1C',
#  'COC1=CC=C(OC)C(CC2=NN=NN2CC2=CC=CO2)=C1',
#  'CC(O)CN1CC2(CC[NH+](CC3=CN=C4C=CC=CN34)CC2)CCC1=O',
#  'CC(C)N1C(CCCl)=NC2=CC=C(S(=O)(=O)C(F)F)C=C21',
#  'CCOC(=O)C1C(SCC(C)C)=CC2=CC=CN=C21',
#  'CCOCC1CCCN(C(=O)NCCC2=CC=C(F)C=C2)C1',
#  'CC(C)(C)C1=NN=NN1C1=NN=C(C2=CC=C(Cl)C=C2Cl)S1',
#  'CC1=NC(C[NH+]2CCC(C3=CSC(N4CCC(C5=CC=CN=C5)=N4)C3)=CC(=O)N2)=C(C)S1',
#  'NC(=O)C[NH+]1CCC(C(=O)NC2=CC(F)=CC(F)=C2)CC1',
#  'CC(=O)NC1=CC(NC(=O)NCC2=NC=C(C)O2)=CC(Cl)=C1Cl',
#  'CC1=C(CC[NH2+]C(C)C(O)N2CCOCC2)C2=NC=C(C(C)(C)C)O2)C=N1',
#  'N#CC(C#N)=C(Cl)C1=CC=C(OC(F)F)C=C1',
#  'O=C1NC2=C(OC3=CC=CC=C32)N(C(C2=CC=CC=C2)C2=CC=CC=C2)C1=O',
#  'CC(C)N(C)C(=O)NCCNC(=O)CC1=CC=C(F)C=C1',
#  'CCCNC1=CC=C([N+](=O)[O-])C(C2=NC3=CC=CC=C3S2)=N1',
#  'COC1=C(Br)C=CC(C(=O)NC2CCCCC2C)=C1',
#  'CC1=CC(F)=CC(S([NH3+])C2CCCC2)=C1',
#  'CC(C)(C)N1CC([NH2+]C2CCOC3(CCCC3)C2)CC1=O',
#  'CN1C(SCCOCC2CC2)=NN=C1C1COC2=CC=CC=C2O1',
#  'CC(C)(CNC(=O)C([NH3+])C1=CC=C(Cl)C=C1)C1=CC=CC=C1',
#  'CCNC1=NC(CN(C)CC2=NC3=CC=CC=C3S2)=NO1',
#  'CC1=NN(C2(C[NH3+])CCC([NH3+])C2)C(C)=C1Cl',
#  'CC1(C)CCCCC1N1C(=O)CC([NH+]2CCCC(C3=CC=C(C=O)C=C3)C2)C1=O',
#  'CCOC1=CC=C(C(=O)NC2=CC=CN=C2N2C=CC=N2)C=C1[N+](=O)[O-]',
#  'CCC1=CC=CC2=NC=CN=C12',
#  'CCNC1=NN=C(SCCC(=O)N(C)CC)C2=CC=CC=C12',
#  'CCOC1=CC=C(F)C(C(=O)[O-])=C1',
#  'CC(CO)C1([NH3+])CCCC(C)C1',
#  'CCCC1=NN(C)C(NC(=O)C(=O)NCCOC)=C1[N+](=O)[O-]',
#  'CC(CC1CC1)N(C)C(=O)C1=NC=CN2C=CN=C12',
#  'COC1=CC=C(NC(=O)C(=O)NCC[NH2+]C2CCCCC2C)C=C1',
#  'CC1=CC=C(C2=NNC(C)=C2NS(=O)(=O)C2=CC=C(C(N)=O)C=C2)C=C1',
#  'C#CCOC1=CC=CC(CN2CCOC(C3=CC=CS3)C2)=C1',
#  'COCC(NC(=O)C1CCCC2=CC=CC=C21)C1=CC=C2C=CC=CC2=C1',
#  'CN(CC(=O)N1CCOCC1)C(=O)NC1C=CC(C(=O)[O-])C1',
#  'CC1=NC(C)=C(CC(=O)NCC#CCOC2=CC=CS2)O1',
#  'CCN1C(=O)C(=CC2=CC=C(C3=CC=CC=C3Cl)C=C2)SC1=NS(=O)(=O)C1=CC=C(F)C=C1',
#  'CN(C(=O)CN1N=C(Cl)C2=CC=C([N+](=O)[O-])C=C21)C1=C(F)C=CC=C1F',
#  'CC1C[NH+]2CCCCC2CN1CC[NH+](C)CCCC(C)(C)C',
#  'CC(CC1=CC=CS1)NC(=O)NCC1=NC=CC=C1N1CCCC1',
#  'C[NH+]=C1CCC(=NC2=CC=CC([N+](=O)[O-])=C2)S1',
#  'N#CSC1=CC=CC=C1F',
#  'COC1=CC=CC=C1C1CCC[NH+]1CC(=O)NC1=CC=C(C)C=C1Br',
#  'CC1=CC=C(C(N)=O)C=C1NC(=O)NC1CCC2=C(Br)C=CC=C21',
#  'CC1=CC(C2=CC=C(S(=O)(=O)NCCC3=CC=CC=C3)N2)C(C)=C1C1COCCO1',
#  'C1=CC(CN2CCOC3CCCCC32)=C2C=CSC2=[NH+]1',
#  'COC(=O)C1=CC=CC=C1S(=O)(=O)NC1CCCCC1C',
#  'CCC(C)C(O)CC1=NC(C)=NO1',
#  'OCCC1CCC[NH+](CC2=NC=CC=C2[N+](=O)[O-])C1',
#  'COC1=CC=C(OC)C(NCC2=[NH+]C=CN2C)=C1',
#  'CC(=O)NC1=CC=C(O)C(NCC(=O)NCCC2=CC=CC=C2O)=C1',
#  'CCN1C(=O)CC(NC(=O)NCCN2CCCCCC2)C1C1=CC=C(C)C=C1',
#  'CC1CCCC[NH+]1CC1C(C(=O)[O-])C2=CC=CC=C2C1',
#  'CC1=CC(C)=CC(NC(=O)C2CN(CC3=CC=NC=C3)CCO2)=C1',
#  'COC1=CC=C(C2CC(C(C)(C)C)C3=C(OC(C)=N3)C2)C=C1',
#  'OCC1(C2=CC=C(Cl)C=C2)CCC1',
#  'O=C(C1=CC=C(OCCl)C=C1)N1CCCOCC1',
#  'COC(=O)C1=CC=C(OC(=O)C2CCCCCC2C(=O)[N+]2=CC=CC=C2)C=C1',
#  'CC1=CC(C#N)=CC=C1S(=O)(=O)N(C)C',
#  'COC1=CC=CC(C2=NN=C(NC(=O)C3=CC=CC=C3SC(F)(F)F)S2)=C1',
#  'COC1=CC=C(COCC2=CN(C)N=C2)C=C1',
#  'O=C(NCC1=CN(C2=CC=CC=C2)N=C1C1=CC=CC(Cl)=C1)C1=CC=CS1',
#  'COC1=CC=C(C2=CC(=O)[O-]C3=NC4=C(C=NN4C(C)=O)C4=CC=CC=C34)C2=O)CC1',
#  'CCCC(=O)NC1=CC=C(N2CCOC(C)C2)CC1',
#  'CC1C2=CC=C(CNC3CN(CCO)C3)N=CN=C2C1',
#  'O=C(NCC1CCOC1)NC(CO)C1=CC=C(Cl)S1',
#  'CC(C)C(C)CC(=O)N1CCCC(C2=NN=NN2C2=CC=CC=N2)C1',
#  'CC(NC(=O)NC1=CC=C(N2CCCC2=O)C=C1)C1=CC=CC=C1',
#  'CC1=CC=C(NC(=O)C2=CC=C(Cl)C(S(C)(=O)=O)=C2)C(=O)S(=O)(=O)C1',
#  'CSCC(=O)NNC(=O)C1=CC(=O)NC2=CC=C(F)C=C12',
#  'CC1=CC=C(C[NH2+]CC2=CC=CN2C)C(C)=C1',
#  'CC1=NC(C)=C(C(=O)NC2CCC3=CC(Cl)=CC=C32)N1C1=CC=CC=C1',
#  'CC(C(=O)[O-])N1C(=O)C2=C(C(C3=CC=CS3)=NN2)C1C1=CC=CS1',
#  'O=C(CCCC1CCCCC1)NC1CCCC1',
#  'NC(C[NH3+])C1=CC=NC(F)=C1',
#  'COC1=CC=C(C(O)CNC(=O)COC2=CC=C(S(N)(=O)=O)C=C2)C=C1',
#  'CC1=CC(=O)C(=CC2=CC(F)=C(F)C(F)=C2F)SC1',
#  'CC(C)N1CCOC(CNC2=NC3=CC=C(Cl)C=C3S2)C1',
#  'COC1=CC=CC=C1CS(=O)(=O)CC1=NN(C2=CC=CC=C2)C2=C1C(=O)NN=C2',
#  'COC1=CC(C(C)=O)=CC=C1OC(C)C(=O)NC1=NC(CCl)=NC=C1C',
#  'CCOC1=CC=C(N2C(=O)NC(=O)C(=CC3=C(C)NC4=CC=CC=C34)C2=O)C=C1',
#  'COCC1=CC(NC(=O)CN2C(=O)NC(C)(C3=CC=C4OCOC4=C3)C2=O)=CC=[NH+]1',
#  'O=C(NNC(=S)NC1CCCC1)C1=CC=C(CN2C=CC=N2)C=C1',
#  'CC1=C(C2=CC=C(C(=O)NCC3CC4CCC3O5)C=C2)C=NN1C',
#  'CCOC1=CC=C(CC(=O)N2CCC(NC(N)=O)CC2)C=C1Br',
#  'CCS(=O)(=O)N1CCC(COC2=CC(C)=C(C)C=C2C(N)=O)CC1',
#  'C[NH2+]C1C2=C(CCCC2)SC(C(C)O)C1',
#  'CSCC[NH+](C)CC1=CN2CCCCC2=N1',
#  'COC1=CC=C(N)C(OCC(O)C[NH+]2CCC3=CC=CC=C3C2)=C1',
#  'CCCC(=O)NC1=CC=C(S(=O)(=O)NC2CCCC2)C=C1',
#  'CC1=NOC(CS(=O)(=O)CC(=O)NC(NC(=O)OC(C)(C)C)C(C)(C)C)=N1',
#  'CB1=NC(SCC2=C(C)ON=C2C)=NC=C1[N+](=O)[O-]',
#  'CCSC1CCCCC1NC(=O)N1CCOCC1',
#  'CC1OCCC1=CC1=CC2=C(N=CN(CC[NH+]3CCOCC3)C(=O)N12)C1CC1',
#  'COC1=CC=C(C(C)NC(=O)NC2=CC=C3COCC3=C2)C=C1C1=CC=CC=C1',
#  'CC[NH+](CC)C1(C(=O)CC2=CC=C([N+](=O)[O-])C=C2)CC2=CC=CC=C2C1=O',
#  'COC1=CC=C(NC(=O)NCCCN2C=C[NH+]=C2)C=C1Cl',
#  'C[NH2+]C(C1=CC=C(OC)C=C1)C1CC(C)(OC)CCC1(C)C',
#  'C=C(C)OC1=CC=C(C)C=C1',
#  'CCC1CCCCN1S(=O)(=O)C1=CC(Br)=C(Br)S1',
#  'CCC1CCC([NH+]2CCC(OC3=CC=CC=C3C)CC2)C1',
#  'CSC1=NC=CN1C1=CC=CC(CNC(=O)C2CCCCC2)=C1',
#  'CCCN1N=CC=C1C(=O)N1CCN2C(=O)NCCC2C1',
#  'CC1=NNN=C1NCC(CO)C1=CC=CC(Cl)=C1',
#  'N#CC1=CC=CC(OCC(C[NH+](C)C)C#N)=C1',
#  'CC(C)[NH2+]CC1CCN(C2=CC=CC(F)=C2F)C1',
#  'CC1=CC=C(N2N=C(C)C=C2C)C=C1C=C1C(=O)NC(=O)N(C)C1=NC1=CC=CC=C1',
#  'CC1=CC(OCC(=O)NC2=NC3=C(CCCC3)S2)=NC(NC2=CC=CC=C2N)=N1',
#  'CC1=NOC(CCCC(=O)N2CCS(=O)(=O)CC2)=C1',
#  'COC(=O)C(C)C(C)[NH2+]C1CC1',
#  'CC1=NC2=NC(SC(C(=O)C3=CC=CC=C3)C3=CC=CS3)CC(C)(C)O2)=C1C1=NC2=CC=CC=C2N1',
#  'CN(C)C(CNC(=O)NC1=CC=NN1C1CCCCC1)C1=CC=CC=C1',
#  'CCC(NC(=O)NC1=C(C)C=C(C)C=C1C)C1=CC=CC=C1',
#  'CC(C)CCC(=O)NC1=CC(Cl)=CC=C1[N+](=O)[O-]',
#  'C[NH+](C)CCCN(C(=O)C1=NC(S(C)(=O)=O)=CS1)C1=CC=CC(C(F)(F)F)=C1',
#  'CC1=CN=CC(NC(=O)N(C)C2CC[NH+](C)C(C)C2)=C1',
#  'COC1=CC=C(NC(=O)C23CC4CC(CC(C4)C2)C3)C=C1OC',
#  'CCN1C(N)=C(N=NC2=CC=C(Cl)C=C2)C1=O)C(=O)NC1=NC(C)=CS1',
#  'CC1=CC(C)=CC(OCCNC(=O)CN2C=NC3=C(SC=C3)C2=O)=C1',
#  'CCCCCC(C)N(C)C(=O)NC1CCCC1',
#  'CC1=CC=C(S(=O)(=O)C2COC2=O)C=C1C',
#  'CN1C=C(C[NH2+]CC2=CC=CC(O)=C2)C(C2=CC=NC=C2)=N1',
#  'CC1CCC[NH+](CCNS(=O)(=O)C2=CC=C(N3C=CC=N3)C=C2)C1',
#  'O=C(NC1CCC(O)CC1)C1=CC(F)=CC(F)=C1',
#  'COC(=O)C1(F)CCN(C(=O)NC2=CC=CN=C2)C1',
#  'CC(C(=O)NC(N)=O)[NH+]1CCCC(C(=O)N2CCCC2)C1',
#  'CC1(COC(=O)N2CC3CCCC3S2)CCCO1',
#  'CCOC(=O)C1(N)CCCC1CCOC',
#  'CC(CS)COCC1=NC2=NC=C(N)N=C2C1=O',
#  'CC1=CC(Br)=CC=C1OCC1=NOC(C2=CC=C(Cl)C=C2)=N1',
#  'CCC(NC(=O)C1=CNN=N1)C(C)(CC)N1CCOCC1',
#  'COC(=O)C1=CC(C(=O)NC2=CC=CN=C2N2C=CC=C(C#N)C2=O)=C2C=CC=CC2=N1',
#  '[NH3+]C1CCOCC1C1CCOC1',
#  'CCOC(=O)C1=C(C[NH+](C)CC(C)(C)C2=CC=CC=C2)OC=C1',
#  'CC1CN(CC(=O)NC2=NN=C(C[NH+](C)C)C(C(F)(F)F)=C2)CCO1',
#  'CC(C)N1N=C(C2CCCCC2)C(=O)NC1C1=CN(CC[NH+]2CCCC2)N=C1',
#  'COC1=CC=C(OC)C(OCC([O-])CO)=C1',
#  'COC1=CC=C(CNC(=O)C2CCOC2C)C=C1CO',
#  'COCCN1CC(C(=O)NC2=CC(C#N)=CC=C2OC2=CC=C(F)C=C2)CC1=O',
#  'COC1=CC=C(N2N=C(C)C=C2C(=O)N2CCCCC(C(N)=O)C2)C=C1',
#  'COC(=O)C1(N)CCC(SC2=CC=CC(F)=C2)C1',
#  'CC(C)[NH2+]CC1=CC=C(OCOC2CCOC3(C)C)C2=CC=CC3=C1',
#  'NC(=O)C1C=CC=CC1C1OC(O)C(O)C(O)C1O',
#  'CCOCC(C[NH3+])C1=CC(C)=CC=C1Br',
#  'CC1=CC=CC=C1S(=O)CCC1CCCCCC1[NH3+]',
#  'CCCS(=O)(=O)[N-]C1=CC=NC(NC2=CC=CN=C2Cl)=C1',
#  'COCC(NC(=O)NCC1=CC=C(N2C=CN=C2)N=C1)C1=CC=CC=N1',
#  'CC(C)CN1C=CC2=C(C=NC3=CC=CC=C23)C(=O)C1=O',
#  'O=S(=O)(CC1CCCO1)N1CCCC1C1=NC2=CC=CC=C2S1',
#  'COC1=CC=C2C(=C1)C(C)(C)N(C(=O)C1=C3N=CC(Br)=CN3N=C1)C2',
#  'COC(=O)C1(NC(=O)C(CC(C)C)C2CCCC2)CCOCC1',
#  'CC1=CC(F)=CC=C1C=NNC(=O)CSC(C)C(C)C',
#  'COC1=CC=C(NC2=C(C(=O)NC3=C(C)N=C(C)S3)SC(C)=C2C)C=C1',
#  'CC1=CC=CC=C1C1CN(CC2=CN=C3N=CC=NC3[NH2+]C(C)(C)C)C(C3=CC=CC=C3)C2)CC1',
#  'CC1(C)C(NC2=NC=C(C(F)(F)F)C2=O)=C(C#N)C2=CC=CC=C21',
#  'CC1CCC(NC(=O)N2C(C)OC3=CC=CC=C32)CC1',
#  'CN(C(=O)C1=NN(C2=CC=C(Cl)C=C2)C=C1)C1CCS(=O)CC1',
#  'FC1=CC=C(C2CC(C3=CC=CC=C3F)=NN2)C=C1',
#  'CCN1C(=O)CC(C(=O)NC2=CC=CC(F)=C2)OC2=CC=CC=C21',
#  'CC1=CSC(CS(=O)CC2=CSC(C3=CC=C(C)C=C3)=N2)=N1',
#  'CC(OC(=O)C1=CC=CO1)C(=O)NC1=CC(F)=CC=C1F',
#  'CC1=[NH+]C=CN1C1CCN(C(=O)NC2=NC=CS2)CC1',
#  'CCCC(CCC)C(=O)NCCS(C)(=O)=O',
#  'C#CCCOC1=C(C)C=NC(CCNS(C)(=O)=O)=C1C',
#  'CN(C)C1=CC=C(C(CNC(=O)C(=O)NC2=CC=C(Cl)C=C2)[NH+](C)C)C=C1',
#  'CC1=NN(C)C=C1C(C)NC1=NN2C(C3=CC=C(OCC(C)C)C=C3)=NN=C2C=C1',
#  'CC=CCCC[NH2+]C(C)C1=CC=C(Cl)C=C1Br',
#  'CC1=C(C(=O)NC(C)C2=CC=C(C3=CC=CC=C3)C=C2)C=CC=C1[N+](=O)[O-]',
#  'NC(=O)C1=CC=C(OC2=CC=C(NC(=O)NC(CO)C#N)C=C2)C=C1',
#  'CC(C)CNC(=O)C1=CC=C(NC(=O)C(C)[NH+](C)C)C=C1',
#  'CCOC1=CC=C(NC(=O)NCC2CCOC2C(C)(C)C)C=C1',
#  'COC1=CC=CC=C1CC(=O)N1CCCC(C2=NC(C)=NO2)C1',
#  'COC1=CC=C(C2=NN=C3SC4SCCN42)C3=O)C=C1OC',
#  'CC1=NN(C2=NC(C)=CC=N2)C(NC(=O)NC2=C(C)C=C([N+](=O)[O-])C=C2Cl)=C1C#N',
#  'CSCC(C)NS(=O)(=O)C1=CC=C(F)C(Cl)=C1',
#  'CC1(C)CCC2(CC[NH2+]CC2C2=CC=CN=C2)C1',
#  'CC1=C(C(=O)N2CCCCCC2)C(=O)N(C)C=C1[N+]([O-])=CC1=CC=CO1',
#  'CC1=CC(C2CC[NH2+]C2C)=CC=C1Br',
#  'CCC1C(=O)NCCN1C(=O)NCC1=CC=C(CN2C=NC=N2)C=C1',
#  'CC1=CC(C(=O)NC2=NC3=CC=CC=C3S2)=C(C#N)C2=C1CCC2',
#  'CC12CC3=CC(NC(=O)C4=CC5=CC=CC=C4N4C)=NC(=O)C3CC12C)C1=CC=C(F)C=C1',
#  'CC1=CC(NC(=O)CN2CCN(S(C)(=O)=O)CC2)=C(C)N1C(C)(C)C',
#  'C#CCN(CC(=O)[O-])C(=O)CN1C(=O)C2C3C=CC(C4)C3C1CC1=CC=CC=C12',
#  'CC1=C(C)C2=C(N=C(OC3=CC=C(C)C(C)=C3)C(C3=CC=CC=C3F)C2)=CS1',
#  'CC(NC(=O)N(C)C1CCCCCCC1)C1=CC=CC=C1Br',
#  'C=CCN(CC#C)C(=O)C1=C(C)C2=CC=CC=C2OC1=O',
#  'CC1=NN(C)C2=C1C1=NC(C3=CC=CC=N3)=NN1C(C)=N2',
#  'OC1CCCC([NH2+]CC2=CC(F)=CC=C2O)C1',
#  'N#CC(=CC1=NN(C2=CC=CC=C2)C(C2=CC=CC=C2)=C1)C1=NC2=C(F)C=CC=C2S1',
#  'CC(C)OC(=O)C(C)[NH2+]C1CCCN1CC1=CC=CC=N1',
#  'O=C1C=C(CSCC2=NOC(C3CC3)=N2)CCCCN1',
#  'CC1=NN(C2C[NH+](C(C)C(=O)NC3=NOC(C)=C3)C2)C(C)=C1',
#  'CCCN(CC1CC[NH2+]CC1)CC1=CC=CC=N1',
#  'CC1=C(NC(=O)C(=O)N2CCC3=C(C=CS3)C2)C2=CC=CC=C2N1',
#  'CCCC(NC(N)=O)C(=O)N(CC#N)CC1CCCO1',
#  'O=C1CC(C2=NC3=CC=CC=C3C(=O)N2)C2CCC(C1)[NH2+](CCO)C2',
#  'CC1=CN(C)N=C1C(=O)NCC(C)OC1=CC=CC(N)=C1',
#  'CC(C)OC1=CC=C(C=NN2C(=O)C3=CC=CC=C3NC2=O)C=C1',
#  'COC1=CC=C(F)C=C1CN1C(=O)C(=CC2=C3OCOC3=C2)SC1=S',
#  'CCOC(=O)C1(C2=CNC3=CC=CC=C23)CCOCC1',
#  'CC(C)NC(=O)C1=CC=C2SCC(=O)NC2=C1',
#  'CCC(C)N(C(C)=O)C(=O)C1=CC=C(SC2=CC=CC=N2)C=C1',
#  'CCOC(=O)CN(C)C(=O)C1=CC(C)=CC=C1O',
#  'CC(OC1=CC=CC=C1C#N)C(=O)NC1=CC=C(C2=NC=CS2)C=C1',
#  'CC1=CC=CC=C1CS(=O)(=O)N(C)CCCC1N=NN=CN1C1CC1',
#  'CC(OC1=CC=C(Cl)C=C1Cl)C(=O)NC1=CC=C(OC2CCCC2)C=C1',
#  'CC1=CC=C2OC(C3CC[NH+](CC3=CC=CC(Cl)=C3)CC(=O)NC23)C=C1C',
#  'COC1=CC=C(S(=O)(=O)N2CCC(C)C2O)C(C(=O)OC)=C1',
#  'CC1=NN(CC2=CC=CO2)C(C)=C1C(=O)N1CC(C)CC(C)C1',
#  'COC1=CC=CC=C1C=C1SC(=S)N(NC(=O)NC(C)(C)C)C1=O',
#  'CC1CCN(C(=O)NCC2CCC(C)(C)C2)CC1[NH3+]',
#  'CCCC1C[NH2+]CCN1CC1=CN=C2C(C)=CC(=O)NC2=C1',
#  'COC1=CC(C2=NOC(CCC(=O)[O-])=N2)=CC(OC)=C1OC',
#  'CCC1=CC=CC(C2CC(C)N3N(CC4=CC=C(F)C=C4)C(=O)C3=C2)=C1',
#  'CC1=NOC(C2=CC(C(=O)N3CCCC(C(=O)NC4CCCC4)C3)=CS2)=N1',
#  'CC(C)N(C)C(=O)C1=CN(C2=CC=CC(C(F)(F)F)=C2)C(=O)C2=CC=CC=C2N1',
#  'CC1=CC=C(C=NNC(=O)C2=CNC3=CC=CC=C23)C(Cl)=C1',
#  'CC1=CC=CC(C(C2CC2)[NH2+]2CC(=O)NCC2)=C1',
#  'CC(C1=NOC(C2=CSC(C3=CC=CO3)=N2)C1)N1CCOCC1(C)C',
#  'CC1(C)CCCCC1(O)CC1=CC=CC=C1',
#  'C[NH+](CC(=O)N1CCC2=C(C1)SC(NCC1=CNC=C1)C(=O)[O-])=COC2=O',
#  'CC1CC2C=CC(N)C([NH+](CC3=CC=NC=C3)CC2)C1',
#  'CC(=O)NNC(SC1CC1)C(F)(F)F',
#  'COC1=CC=CC(CCC(=O)NC2=CC=C3OC(C)(C)C(C)=CC3=N2)=C1',
#  'COC1=CC(OC)=C(C2=NN=C3SC(CC#N)=CC(=O)O3)=C2OC(C)C)C1=O',
#  'COC(=O)C1CCC[NH+](C2CCN(CC(F)(F)F)C2)C1',
#  'CC1=CC=C(C2=NN3C(C)=NN=C3S2)C=C1NC(=O)CCC1=CSC=C1',
#  'CC1=CSC2=NC=C(S(=O)(=O)NC3=CC(C(=O)NC(C)C)=NN3)C=C12',
#  'COC1=CC=C(Br)C=C1S(=O)(=O)NCC1=CC=CC(C(N)=O)=C1',
#  'CC1CCCCC1NC1=NC=NC2=C1CCC(=O)N2CC1=CC=C(F)C=C1',
#  'CCC(C)C([NH2+]C)C1CN(C)CCO1',
#  'CC1=C(C)OC(CNC(=O)C2(C3=NOC(C4(C)C)=NO4)CC3)=CC=[NH+]2)=C1',
#  'CCC(C)C([NH2+]C)C1CN(CC)CCO1',
#  'COC1=CC(C=CC(=O)C2=CC(F)=CC=C2F)=CC(OC)=C1OC',
#  'CC1=CC(CN(C)C2CCCCC2C#N)=CN1C',
#  'CC1CCCCN1C(=O)CSC1=CC=C(C(N)=S)N=N1',
#  'CCC(CC)OC1CCCC(OC)C1',
#  'CCC(C)C(CC1=CC(C(C)=O)[NH+]=N1)C(C)C',
#  'CC1CSC(SC(C)C2=NC=C(C3=CC=CC(Cl)=C3)O2)=N1',
#  'C=CCC1=CC=CC=C1OS(=O)(=O)C1CCOCC1',
#  'CCC1OC2=CC=C3C(=O)C=CC(OCC4=CC=C(OC)C=C4)=CC(=O)N3C2=O)C1C',
#  'COC1=CC=C2C(CNC(=O)C(=O)NC3=CC=C4OCCOC4=C3)=CC(=O)OC2=C1',
#  'COC1=CC=C(C2=CC=NC(C3CCCN(C(=O)C4=CC=NO4)C3)=C2)C=C1OC',
#  'CC1=CC=C(C)C2=C1N=C(N(CC1CC3COCC[NH2+]3)S1)S2',
#  'CC(OC1=CC=C(F)C=C1)C(=O)N(C)CC1CCCCO1',
#  'COC(=O)C=CC1=CC=C(N(C)CC(=O)NC2=CC=CC=C2Cl)[NH+]=C1',
#  'CC1=NC=CN1CC(C)C(C)O',
#  'CSC1=CC=CC(NC(=O)C2CC3CCC2C3)=C1',
#  'COC(=O)C(C)(C)CN(C)C1CCC2=CC=C(OC)C=C21',
#  'C#CCC(C)OC(=O)C[NH+]1CCC2=C(C=CS2)C1',
#  'COC(=O)CC(C)NC1=CC=C(C(C)[NH3+])N=N1',
#  'CC1=NC=CN1C1=CC=C(C(Br)C(=O)[O-])C(C)=C1',
#  'CCOC(C)C1=NC(CN(C)C(=O)C2=CC=CC(C)=C2)=NO1',
#  'CC(C)(C)N(CC(=O)[O-])C(=O)C1=C(F)C=CC(O)=C1F',
#  'CC1=NNC(C)=C1C(CC(C)C)NC1=CC=CC2=NC=CC=C12',
#  'CC(NS(=O)(=O)C1=CC=CC=C1)C1=NC(C2=CC=CC=C2F)=NO1',
#  'O=C(CCC1=CC=CC=N1)N1CCCCCC1C1=CC=CS1',
#  'CC1=CC=CC(NC(=O)C2=CC(OCC(F)(F)F)=NN2C)=C1',
#  'C=CCOC1=CC=CC(C(=O)NC2CCCC2(C)C)=C1',
#  'C[NH2+]C(C1=CSC=C1C)C1CCC1',
#  'CN(CC1=CN(C2=CC=CC=C2)N=N1)C(=O)C(C1=CC=CC=C1)C1=CC=CC=C1',
#  'O=C(CN1C=C(C(=O)[O-])C=C1)C1=CC=CC=C1Br',
#  'CCCCNC(=O)CCNC(=O)N1N=C(C2=C(O)C=CC=C2OC)CC1C',
#  'O=C(CSC1N=C(C2=CC=CC=C2)N=N1)NCC(O)C1=CC=CO1',
#  'CC1CN(CC2CO2)CSC1N1CC2CC=CCC2C1',
#  'CC(=O)NC(CSCC1=CC=C(N2C=NN=N2)C=C1)C1CC1',
#  'CC1CC(C(=O)NC2=NC=C(Cl)C=C2Cl)CCO1',
#  'COC1CC[NH+](C2=[NH+]C3=CC=CC=C3N=C2N)CC1',
#  'O=C(C1=CC=NC2=CC=CC=C12)N1CCC2=C(C1)C(C=NNC(N)=O)=C(C1=O)C1=C2CCC1',
#  'C[NH2+]C(CC1=CN(CC)N=C1)C1([NH+]2CCCC2)CCCC1',
#  'CC1=NN(C(C)C)C(C)=C1C(=O)NCC1=CC=C(CS)O1',
#  'C=CCCCN(C)C(=O)C1=CC(C(C)(C)C)=NO1',
#  'CC(C1=NC(C2=CC=CC(F)=C2)=NO1)C1=NN2C(=O)C=C(CN3CCOCC3)N=C2S1',
#  'COC1=CC=C(N2C=NN=N2)C=C1C(=O)NC1CCCCC1',
#  'CC(=O)C1CC[NH+](CC(=O)N2CCNC2=O)CC1',
#  'CCN(CC1=NOC(C2=CC=CC=C2)=N1)C(C)C1=CC=C(C#N)C=C1',
#  'CC1=CC(C)=C(S(=O)(=O)NCC2=CC=C(S(C)(=O)=O)O2)C(C)=C1',
#  'CN(CC[NH+]1CCCCC1)C(=O)C1CC2=CC=CC=C2O1',
#  'COC1=CC=CC=C1C(=O)NC1=CC2=C(C=C1C1=CC=C(Cl)C=C1)CC(=O)N2',
#  'COC1=CC=CC=C1C(=O)N1CCCC(C(=O)NC2(C3=C(F)C=CC=C3F)CCC2)C1',
#  'CCC1=CC=CC=C1NC(=O)CSC1=NN=C(C2=CC=C(S(=O)(=O)[O-])C=C2)O1',
#  'NS(=O)(=O)C1=CC=CC(N2CCS(=O)(=O)CC2)=C1',
#  'CC1CN(C(=O)NC2CC[NH+](CC3=CC=CC=C3)C2)CC(C)O1',
#  'CSCC(C)(O)COC(C)(C)C',
#  'CC1=CC=CC(C)=C1C(=O)N1CCC(C(=O)NC2=CC=CC(Cl)=C2C#N)CC1',
#  'CC(SC(C)C(C)O)C(=O)NC1=CC=CC(Br)=C1',
#  'CC(C(=O)NCC1=NC(C(C)(C)C)=CS1)C1(O)CCC1',
#  'CC(CC1=CC=CS1)NC(=O)C1=CN(C2CCCN2C(=O)C2=CN(C)N=C2)N=N1',
#  'CCC1=CC=C(N2C(SC(C)C(=O)NC3=CC=CC4=NC(C)=NC4=C3Cl)=NN=C2N2CCOCC2)C=C1',
#  'COC(=O)CCCS(=O)(=O)CC1=NC(C2CC2)=NO1',
#  'CC1=CC(OCC(=O)NC(CC(C)C)C(C)(C)C)CC(=O)NC1=O',
#  'COC1=CC=C(C2=NN=C(NC(=O)C=CC3=CC=C(F)C=C3)O2)C=C1',
#  'O=C(NCC1=CC=C(C2=COCC2)C=C1)C1=CN=CN1',
#  'CC(OC(=O)C1=CC=C2C=CC=CC2=C1)C(=O)NC1=CC=CC=C1Br',
#  'CCC(C)N(C)C(=O)N(CC1=CC=CO1)CC(C)C',
#  'NC(C1=CC=CS1)C1CC=CCC1',
#  'COC1=CC(N)=CC=C1SCC1CN(C)CCO1',
#  'C=CCN1C(SC(C)C(=O)NC2=CC=C([N+](=O)[O-])C=C2)=NN=C1C1=CN2C=CSC2=N1',
#  'CC1=CC=CC=C1COC1CCN(C2=NC(Cl)=NC3=CC=CC=C23)CC1',
#  'CN1C(=O)N(C)C2=NN(CC(=O)NCC#CC3=CC=CC=C3)C(=O)C2=C1C(Cl)=C(Cl)Cl',
#  'CC1=NC(CN(C)S(=O)(=O)C2=CC(Br)=CC=C2Cl)=CS1',
#  'COC1=CC(Br)=C([N-]S(=O)(=O)C2=CC=C3OC(C)C(=O)NC3=C2)C=C1OC',
#  'COC(=O)C(C)(C)C[NH+](C)CC1=CC=CC=N1',
#  'CC1CCCC(N(CS)C(=O)OC(C)(C)C)C1',
#  'CC(C1=NOC(CC2=CC=C(F)C=C2)=N1)N1CCOCC1=O',
#  'CCOC(=O)C1=CC=C(NC(=O)C2=CC([N+](=O)[O-])=CC([N+](=O)[O-])=C2)C(C(F)(F)F)=C1',
#  'O=C(C1CCOCC1)N1CCCC1C1[NH+]=C2C=CC=CC2=[NH+]1',
#  'CCN1CC(=O)N2C(C(=O)OC3=CC=C(Cl)C=C3C)CCC2=N1',
#  'CCC1=CC=CC=C1OC1CCC([NH2+]C)C1',
#  'CC1=CC=C(NC(=O)C2COC3=CC=CC=C32)C=C1[N+](=O)[O-]',
#  'O=C(C1CCCC1)N1CCN(CCS(C)(=O)=O)C2=CC=CC=C21',
#  'COC1=CC=C(C2[NH+]=NC3=C2C(=O)N(CC(=O)NCC2=CC=C(C)O2)C3=O)C=C1',
#  'COC1=CC=CC=C1C(NC1=NN2C(C)=NC3=CC=CC=C3C2=[NH+]1)C1=CC=CC=N1',
#  'C[NH+](CC=CC1=CC=NC=C1)C1CCCC1',
#  'CC1=CC=CC=C1C[NH+](C)CCOC1=CC=C(F)C=C1',
#  'CNC1=NC(C)=CC(C2CCC[NH+]2CC2=CC=CC=C2)=N1',
#  'CC(C)C1=CC=C(CCNC(=O)C[NH+](C)C2CCCCCC2)C=C1',
#  'CCN1C=C(C2=CC=C(C(F)(F)F)C=C2C(=O)OC)C(C#N)=C1C',
#  'O=C(NCC1CC1)C1CCCN1S(=O)(=O)C1=CC=CC=C1',
#  'CC1=NC2=CC=CC=C2N1CC(Cl)=CCl',
#  'COC1=CC=C(CCC(=O)NCC(C)(O)C2=CC=C(Br)C=C2)C=C1',
#  'O=C(CS(=O)(=O)C1=NN=C(C2CC2)N1C1=CC=C(Cl)C(Cl)=C1)NC1=CC=C(F)C=C1F',
#  'COC1=CC(C=C2SC(=O)N(C(C)C(=O)NC3=CC=CN=C3)C2=O)=CC=C1OC(C)C',
#  'CC(CC1=CC=CS1)NC1=NC=C(CSC2=NN=CS2)S1',
#  'CCC1=NN(C)C=C1C[NH2+]CC(=O)N1CCC2=C(C=CS2)C1',
#  'CC1CCCN(C(=O)CN2CCOCC2)CC1O',
#  'CCCNC(=O)C(C)NC1=CC=CC=C1OC1CCCC1',
#  'CC1=CC2=CC=C3C(=O)N(CC4CCCCC44)C2=C1C(=O)C(C)(C)O',
#  'CCOCC1CC[NH+](CC2CC3=CC=CC=C3S2)C1',
#  'CCCC1=NN=C(NC(=O)C2=CC(C3=CC=C(F)C=C3)=NC3=CN=C2)S1',
#  'CC(C)(C)OCC1=CC=C(N2C(=O)C3CC(C4=CC=C(O)C=C4)=CC(O)N3NC2=O)C=C1',
#  'CN(C1=CC=C(NS(=O)(=O)C2=CN3C=CC=N3)C=C2)C=C1C(N)=O',
#  'CC1=CC([N+](=O)[O-])=C2C=CC=CC2=[NH+]1',
#  'COC(=O)C1=C(C)N=C(C2=CC=CC=C2)C(C2=CC=CC=C2C(F)(F)F)O1',
#  'CC(C)C(NC(=O)NN=CC=CSC1=CC=CC=C1)C1=CC=CC=C1',
#  'COC1=NC=CC=C1C(=O)N1CCC(NC2=NC=CC=N2)CC1',
#  'CC(=O)NC1=CC=C(C)C(NC(=O)C2=CC=NC(Br)=C2)=C1',
#  'CSC1CCC(NC(=O)CN2C(=O)OC3=CC=CC=C32)C1(C)C',
#  'O=C(CCCOC1=CC=CC=C1F)NC1=CSC=C1',
#  'CC1=NN(C)C=C1C(C)N(C)C(=O)C1CC(=O)NC2=CC=CC=C21',
#  'O=C(NCC1=CC=[NH+]C(N2CCCCC2)=C1)NC1CCC1',
#  'COCC1CC[NH+](CC[NH2+]CC(C)OC)CC1',
#  'CCCOC1=C(Cl)C=C(C=O)C=C1C#N',
#  'CC1=NC=C(N)C(CCC(=O)NC(C#N)C(C)(C)C)=N1',
#  'COC1=CC=CC(CNC(=O)C2=CC=CC(Br)=N2)=C1OC',
#  'COC(=O)CCN1C(CCC2=CC=CC=C2)=NC2=C(C3=C(CCC3)S2)C1=O',
#  'CC1=C(C(=O)NCC(C)(O)C2=CC=CC=C2Br)C=NN1C(C)C',
#  'CCC1=CC=CC=C1C[NH2+]C(C1=CC=CC=C1)C1=CC=CN=C1',
#  'CCC(CCO)NC(=O)NC1CC(=O)N(CCC2=CC(Br)=CC=C2C)C1',
#  'COC1=CC2=C3C=CC=CC3=[NH+]C([O-])=C(C)C2=N1',
#  'CC1=CC=C(Br)C=C1S(=O)(=O)NC1(C2=CC=CC=C2F)CCOCC1',
#  'CCOC(=O)NC1CCCCC1(C(=O)[O-])[NH+]1CCCCC1',
#  'O=C(NC1=C([N+](=O)[O-])C=CC=C1Br)C1=CC=CC=C1N(CCl)CO',
#  'CSC1CCC(NC(=O)NCC2=CC=CC(C(N)=O)=C2)C1',
#  'CNC(=O)C1=CC=C(C[NH+](C)CC2=CN(C3=CC=CC=C3)N=C2C)C=C1',
#  'CC1=CC(F)=CC=C1S(=O)(=O)NC(C)CCC1=CC=CS1',
#  'COC1=CC=C(C2CC(=O)C3=C(C2)N(CC2=CC=C(Br)C=C2)N=C3C)C=C1',
#  'CC1=NOC(C)=C1S(=O)(=O)[N-]C1=CC=C(NC(=O)N2CCCCC2)C=C1',
#  'N#CC1=CSC(CN2CC[NH+](CC3=CN4C=CC=CC4=[NH+]3)CC2)=C1',
#  'COC(=O)C1=CC=C(COC2=CC=CC([N+](=O)[O-])=C2C(=O)[O-])C=C1',
#  'COC1=CC=CC(COC(C)C(=O)NC2=CC=C([N+](=O)[O-])C(C)=C2)=C1',
#  'CC(SCC1=CC=CC=C1)C(=O)NC1=CC=CC(Cl)=C1',
#  'CC1=CC(NC(=O)N2CCN(C3=[NH+]C4=CC=CC=C4N3)CC2)=CC(C)=C1Cl',
#  'CC1(C2=CC=C3OCOC3=C2)NC(=O)N(CC(O)COC2=CC=CC=C2)C1=O',
#  'CC1=CC(C)=NC(C(C#N)C(=O)CSC2=NN=C(C)N2C2=CC=C(F)C=C2)=N1',
#  'CC1=CC(CO)=CC(Cl)=C1OC(C)C(C)O',
#  'COC(C)C([NH3+]C)C1CCOCC1',
#  'COC(=O)CCCS(=O)(=O)C1=CC=CC=C1Cl',
#  'FC1=CC=C(C=NNC2=NN=NN2)C=C1Br',
#  'CC1=NN(C2=NN(C)C(C(=O)NC(C)C3=CC=CO3)=N2)C(C)=C1',
#  'COC(CNC(=O)C1=CC=C(OC2=CC=CC=C2)C=C1)C1=CC=C(Cl)C=C1',
#  'CC(=O)N1CCCC1C(=O)NC1=CC=CC(CC[NH+]2CCCC(C)C2)=C1',
#  'CCC1=NN(C)C=C1C[NH2+]C(C)C1=NC(C2=CC=CC=C2)=NO1',
#  'COC1=CC=CC(CCC(=O)OC2=C(C)C=CC=C2C)=C1',
#  'CC(O)CC[NH+](C)CC1=CC(C(N)=O)=CS1',
#  'CC1=CC=C(CNC(=O)CSCC2=C(C)N=C3SC(C4=CC=CC=C4)=CC3=O)=C2C)C=C1',
#  'COC(CNC(=O)NC1=CC=CC=C1C(F)(F)F)CC1CC1',
#  'NN1C(SCC(=O)NC2=CC=C(F)C=C2)=NN=C1C1=CC=C(Br)C=C1',
#  'CC(CNCC1=CC(F)=CC(F)=C1)C[NH+]1CCCCC1',
#  'ClCC1=NC=C(F)C=C1CSC1CC2=CC=CC=C2C1',
#  'CC(NC1=CC=C(CC(N)=O)C=C1)C1=C(F)C=CC=C1F',
#  'O=C(COC(=O)C1=CC=CC2=NC=CC=C12)N1CCN(C2=NC3=CC=CN3C=N2)CC1',
#  'O=C1C(=CC2=CC=CC(Br)=C2)SC(=NC2=NC3=CC=CC=C3C(=O)N2)C1',
#  'CC(C(=O)NCC1=CC=CC=C1)C1=CC=CC=C1N',
#  'COC1=CC=CC=C1C1C2=CC=C(C)C=C2N(CC(=O)N2CC(=O)N(C)C3=CC=CC=C34)C(=O)N2C2C3=CC=CC=C3C=CC21',
#  'COC1=CC2=C(C=C1OC)C(C1=CC=CC=C1Br)C1=C([O-])N(CCC(=O)N(C)C)C(C)=NC2=N1',
#  'CCN1C(CN2CCCC2)=NN=C1SCC(N)=O',
#  'CCC(C)CN(CC)C(=O)NCC1CC2=CC(F)=CC=C2O1',
#  'CCN1C(SCC(=O)C2=CC=C(Br)C=C2)=NN=C1C1COCC1',
#  'CC1CCCCN1C(=O)C1=CC(C2CC2)=NC2=CC=C(Br)C=C12',
#  'CC1=C(C[NH2+]C(C)C(O)C2=CC=CC=C2)N2C=CC=C(Cl)C2=N1',
#  'COC1=CC=C(C2C3=C(CC[NH+]2C)C([O-])=CC2=CC=CC=C23)C=C1C(N)=O',
#  'N#CC1=CC=CC(C(=O)NC2=CC=C3OCOC3=C2)=C1',
#  'O=S(=O)(C1=CC=CC=C1Br)N1CCN(C(=O)OCCO)CC1',
#  'CC1=CC=CC(NS(=O)(=O)C2=CC=CC(NC(=O)C3=C(C)OC=N3)=C2)=C1C',
#  'CC1=CC(C)=C(C(=O)NC(CO)CC2=CNC3=CC=CC=C23)C1N',
#  'CC(NC(=O)NC1=NN(CC2CCCO2)C=C1)C1=CC=C(S(N)(=O)=O)C=C1',
#  'O=C(NCCC1=CN2CCOC2=C1)C1=CC=C(CN2CCOCC2)C=C1',
#  'CCOC1=CC=CC=C1OC1CCN(C(=O)C(C)(C)OC)C1',
#  'CC(NC(=O)CCCCC1=C(C)N=C2C=CC=CN12)C1=CC=CC=N1',
#  'COC1=CC=C(C2(CNC(=O)CN3C(=O)CCC3=O)CCO2)C(C)=NN1C',
#  'CCCC(=CC(=O)OCC1=NN=CN1C)CCC1=CC=CO1',
#  'COC1=CC(CC(=O)NC2=NC3=C(COCC3)S2)=CC=C1OCC(N)=O',
#  'O=C(CC1=CC=C2OCOC2=C1)NC1=CC=CN=C1N1CCCC1',
#  'CC(=O)ON=C1C(=O)N(CC2=CC=CC=C2)C(=O)C1C1=CC=CC=C1']

# %%
calc_qed = RewardQED() # qed = calc_qed(smi, debug=True)[1]
calc_logp = RewardPenalizedLogP() # _, clogp, sascore, numring, penalizedlogp = calc_logp(smi, debug=True)

# %%
frames = []

for i, smiles in enumerate(smiles_per_z):
    scores = {"LogP":[], "SAscore":[], "PenalizedLogP":[], "QED":[]}
    for smi in smiles:
        qed = calc_qed(smi, debug=True)[1]
        _, clogp, sascore, numring, penalizedlogp = calc_logp(smi, debug=True)
        scores["QED"].append(qed)
        scores["SAscore"].append(sascore)
        scores["PenalizedLogP"].append(penalizedlogp)
        scores["LogP"].append(clogp)
    df = pd.DataFrame.from_dict(scores)
    df["SMILES"] = smiles
    df["latent_vector"] = i
    frames.append(df)

# %%
df_merge = pd.concat(frames, ignore_index=True)
df_merge.to_csv(os.path.join(output_dir, "pointwise_distribution_ZINC.csv"), index=False)
df_merge.head()
# Out:
#       LogP   SAscore  PenalizedLogP       QED  \
# 0  2.75930  1.836258       0.923042  0.634327
# 1  1.86420  3.446696      -1.582496  0.589970
# 2  3.10792  2.441833       0.666087  0.575373
# 3  2.21920  3.858497      -1.639297  0.858051
# 4  2.37330  2.571521      -0.198221  0.718467
#
#                                               SMILES  latent_vector
# 0     O=C(NNC(=O)C1=CC=C(F)C=C1)C1=CC2=CC=CC=C2C=C1O              0
# 1  CN(C)C1=NC(N2CCC(NC3=CC=C([N+](=O)[O-])C=N3)CC...              0
# 2               COCCCNC1=NC=NC(CSC2=CC=C(C)C=C2)=C1N              0
# 3     COC1=CC=CC(C(=O)C[NH+](C)C2CCC3=CC=CC=C32)=C1F              0
# 4                C1=CC=C(C2=NOC(CCC3=CSC=C3)=N2)N=N1              0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from umap import UMAP
sns.set_theme(style="whitegrid")

# %%
points = PCA(n_components=2, random_state=2021).fit_transform(latent_vectors)
#points = UMAP(metric="euclidean", n_components=2, random_state=2021).fit_transform(latent_vectors)

# %%
df_z = pd.DataFrame(latent_vectors)
df_z.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.488609  0.676011 -0.418451 -0.806521  0.555876 -0.705504  1.130858
# 1  0.141464 -0.654448 -0.672104  0.870368  1.003245 -0.366450  1.128052
# 2 -0.569924  0.246918  0.511292 -0.439804  1.790240  0.180929  0.381956
# 3 -0.827718 -1.496504 -1.517695 -1.037998  0.662567 -0.624228 -0.643762
# 4 -0.515867 -0.479743 -0.537734 -0.717472 -0.118957  1.229855 -0.595299
#
#          7         8         9   ...        54        55        56        57  \
# 0  0.645002  0.106414  0.422155  ...  0.972575  0.412191 -0.132086 -0.673351
# 1  0.792584 -1.750842 -0.808869  ...  0.244745  0.370906  0.414232  1.196694
# 2  0.514857  0.591672  1.900322  ... -0.367205  0.581342 -1.286154  0.851788
# 3 -0.686254  0.441222  0.855880  ... -1.024729 -1.040208 -0.218594  1.074709
# 4  1.595965  1.583657 -0.185138  ... -1.343985 -0.581827 -0.592386  0.291863
#
#          58        59        60        61        62        63
# 0  1.222222 -0.926413  1.424994 -0.124790  0.705492  0.719548
# 1  1.082473  0.276918  0.930367  0.335000  1.794096 -0.952598
# 2  0.684467 -1.346683 -0.977484 -1.514921 -1.071030  0.353427
# 3  0.469758 -1.487871  0.903421 -0.427842  0.055226  0.635421
# 4 -0.990286 -0.273891  0.956009  0.141895 -0.580610 -0.734759
#
# [5 rows x 64 columns]

# %%
df_points = pd.DataFrame(points, columns=["PC1", "PC2"])
df_points = df_points.merge(df_z, left_index=True, right_index=True)
df_points.to_csv(os.path.join(output_dir, "pointwise_pca_ZINC.csv"), index=False)
df_points.head()
# Out:
#         PC1       PC2         0         1         2         3         4  \
# 0  0.513968  4.870681  1.488609  0.676011 -0.418451 -0.806521  0.555876
# 1  1.558254  5.317702  0.141464 -0.654448 -0.672104  0.870368  1.003245
# 2  0.816648 -1.434124 -0.569924  0.246918  0.511292 -0.439804  1.790240
# 3  5.532761 -1.547209 -0.827718 -1.496504 -1.517695 -1.037998  0.662567
# 4 -3.738698 -4.768631 -0.515867 -0.479743 -0.537734 -0.717472 -0.118957
#
#           5         6         7  ...        54        55        56        57  \
# 0 -0.705504  1.130858  0.645002  ...  0.972575  0.412191 -0.132086 -0.673351
# 1 -0.366450  1.128052  0.792584  ...  0.244745  0.370906  0.414232  1.196694
# 2  0.180929  0.381956  0.514857  ... -0.367205  0.581342 -1.286154  0.851788
# 3 -0.624228 -0.643762 -0.686254  ... -1.024729 -1.040208 -0.218594  1.074709
# 4  1.229855 -0.595299  1.595965  ... -1.343985 -0.581827 -0.592386  0.291863
#
#          58        59        60        61        62        63
# 0  1.222222 -0.926413  1.424994 -0.124790  0.705492  0.719548
# 1  1.082473  0.276918  0.930367  0.335000  1.794096 -0.952598
# 2  0.684467 -1.346683 -0.977484 -1.514921 -1.071030  0.353427
# 3  0.469758 -1.487871  0.903421 -0.427842  0.055226  0.635421
# 4 -0.990286 -0.273891  0.956009  0.141895 -0.580610 -0.734759
#
# [5 rows x 66 columns]

# %%
fig, ax = plt.subplots(1,1,figsize=(4,4))

ax.scatter(points[:,0], points[:,1], c=np.arange(len(points)), cmap=plt.get_cmap("tab10"))

for i in range(len(points)):
    ax.text(x=points[i,0]+0.05, y=points[i,1]+0.05, s=f"#{i}", fontsize=16)

ax.axvline(x=0, c='k', linestyle='--', linewidth=1)
ax.axhline(y=0, c='k', linestyle='--', linewidth=1)
ax.set_xlabel("PC1", fontsize=20)
ax.set_ylabel("PC2", fontsize=20)

plt.tight_layout()
plt.savefig(os.path.join("figures", "PCA_SmilesVAE_ZINC.png"), dpi=300)
plt.show()

# %%
def show_kde(df, target_col, drop_zero=False, filepath=None):
    fig, ax = plt.subplots(1,1,figsize=(6,4))
    if drop_zero:
        sns.kdeplot(data=df[df[target_col] != 0.], x=target_col, hue="latent_vector", ax=ax, palette="tab10")
    else:
        sns.kdeplot(data=df, x=target_col, hue="latent_vector", ax=ax)
    
    #ax.set_title(target_col, fontsize=28)
    ax.set_xlabel(target_col, fontsize=20)
    ax.legend().set_visible(False)
    
    plt.tight_layout()
    plt.savefig(filepath, dpi=300)
    plt.show()

# %%
show_kde(df_merge, "QED", drop_zero=True, filepath=os.path.join("figures", "pointwise_distribution_SmilesVAE_ZINC_qed.png"))
show_kde(df_merge, "SAscore", drop_zero=True, filepath=os.path.join("figures", "pointwise_distribution_SmilesVAE_ZINC_sascore.png"))
show_kde(df_merge, "LogP", drop_zero=True, filepath=os.path.join("figures", "pointwise_distribution_SmilesVAE_ZINC_logp.png"))
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
